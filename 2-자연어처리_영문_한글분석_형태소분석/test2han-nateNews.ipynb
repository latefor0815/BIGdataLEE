# %% [markdown]
# ## 한글 형태소 분석 ,시각화, 워드 클라우드 등.
# ### 형태소 분석, 품사 태깅.
# ### 데이터 : 샘플 데이터 , 페이스북 전자 신문에서 크롤링 한 임시 데이터로  대체
# ### 설치 가 조금 복잡함.
# ### 1) jdk 17 이상 2) JPype(자바, 파이썬 연결하는 도구) 3) konlpy 패키지 설치.
#
# ## 주의사항, JPype 버전 1.4,  파이썬 버전 3.10.7 다운그레이드
# ## 시스템 환경 변수 , ex) JAVA_HOME : 경로 추가 하기. jdk 17
# ### 변수명 : JAVA_HOME (동일하게)
# ### 시스템 환경 변수의 경로 값 예제: C:\Program Files\Java\jdk-17
# ### 변수명 : Path
# ### 경로 : C:\Program Files\Java\jdk-17\bin
#
# ## 파이썬 3.10.x , 예) 3.10.7 버전으로 다운 받기.
# ### 시스템 환경 변수 추가 작업
#
# ### 변수명 : Path
# ### 경로C:\Python\Python39\
#
# ### 변수명 : Path
# ### 경로C:\Python\Python39\Scripts
#
# ### cmd -> python -V
#
# ## 2) JPype(자바, 파이썬 연결하는 도구)
# ### 다운로드 사이트 주소 : https://www.lfd.uci.edu/~gohlke/pythonlibs/#jpype
# ### JPype 검색하고, 버전은 JPype1‑1.4.0‑cp310‑cp310‑win_amd64.whl 받아서,
# ### 해당 다운로드 받은 폴더 이동하고, 해당 폴더 검색경로에서, cmd 실행하고,
# ### cmd -> pip install JPype1‑1.4.0‑cp310‑cp310‑win_amd64.whl
# ### 업그레이드 경고창 뜨면 :
# ### python.exe -m pip install --upgrade pip
# ### 업그레이드 후 , 다시 설치
# ### pip install JPype1‑1.4.0‑cp310‑cp310‑win_amd64.whl
# ### , 명령어 붙여넣기.
# ### pip install konlpy
#
# ### 코드 실행시, 설치한(다운그레이드한 버전, 3.10.7) 선택,
# ### 해당 쥬피터 노트북 관련 커널 설치도 자동으로 함.

# %% [markdown]
# # 용어 정리
# ## 형태소 , 형태소 분석
# ### 형태소: 언어에서 의미가 가장 작은 단위.
# ### 형태소 분석: 형태소, 어근, 접두사/접미사, 품사 등 다양한 속성 구조.
# ### 품사 태깅 예) 상용 이가 좋아 하는 음식 은 국밥 이다.
# ### 음식 : NNG, 이가/JKM , 좋아하는/VV, 이다/EFN , 높임말 : 하신다 -> 신/EPH
# ### 품사 태깅 해주는 패키지 : Hananum, Kkma, Komoran, Okt(Twitter 제공)
# ### Okt , 명사 /Noun , 에/ Josa, 먹는/ Verb , 다/Eomi

# %% [markdown]
# # 샘플 데이터 사용.
# #

# %%
# 최초 실행 때는, 설치 후에 주석하기. 
# !pip install matplotlib
# !pip install wordcloud
# Out:
# Requirement already satisfied: matplotlib in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (3.9.1.post1)
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from matplotlib) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: wordcloud in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from wordcloud) (2.0.1)
# Requirement already satisfied: pillow in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from wordcloud) (3.9.1.post1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from matplotlib->wordcloud) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from konlpy) (1.5.0)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from konlpy) (5.2.2)
# Requirement already satisfied: numpy>=1.6 in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from konlpy) (2.0.1)
# Requirement already satisfied: packaging in c:\users\it\documents\bigdatamlvisual501\.venv\lib\site-packages (from JPype1>=0.7.0->konlpy) (24.1)
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import json
import re 
# Okt , 한글 품사 태깅하기위한 모듈, 도구.
from konlpy.tag import Okt
from collections import Counter
import matplotlib
import matplotlib.pyplot as plt 
from matplotlib import font_manager, rc 
from wordcloud import WordCloud

# %%
# 샘플 데이터 읽어서, 메모리에서 확인해보기. 
inputFileName = "./sampleNateNews.json"
data = json.loads(open(inputFileName,"r",encoding = "utf-8").read())
data
# Out:
# [{'subject': ' 떡 드세요  박세리  쏟아진 명언집   3 5% 으뜸 파리올림픽 '},
#  {'subject': '숨진 권익위 간부 사망 사건  부검 없이 종결키로'},
#  {'subject': '기자회견 중 쓰러진 김예지  회복 후 병원 이송'},
#  {'subject': '하윤경  권모술수 주종혁  실제 성격은 큐트보이  12시엔 '},
#  {'subject': '엔하이픈  ROMANCE   UNTOLD   日 레코드협회 첫  플래티넘  인증 획득'},
#  {'subject': '광주 전남 7월 주식 시장 활발 삼성전자 가장 많이 거래'},
#  {'subject': '김재중  16년만 드디어 SBS  인기가요  출격 SM 퇴사 후 처음'},
#  {'subject': '가평군   칼봉산휴양림 목공체험장 운영  민간 위탁 체결'},
#  {'subject': 'SM  전직원에 20억 스톡그랜트 지급 1인당 50주'},
#  {'subject': '넘어지려는 노인 잡아줬는데  폭행  신고 CCTV로 억울함 밝혀내'},
#  {'subject': '與  김경수 복권 여야 협치 구심점 될 것 '},
#  {'subject': ' 야 4885  영화  추격자  실존인물  마약 판매로 검거 무슨 일'},
#  {'subject': '24살 BJ와 포착된 방시혁  관광지 안내해준 것뿐 '},
#  {'subject': '롯데물산  두 번째 지속가능경영보고서 발간  2040 탄소중립 로드맵 실천 강화 '},
#  {'subject': '구급차로 옮겨지는 김예지 선수'},
#  {'subject': '환하게 웃으며 답변하는 김예지'},
#  {'subject': '오직 마카오에서만  일상탈출 액티비티 8'},
#  {'subject': '이스라엘 공격 고심하는 이란  가자 휴전시 보복안 폐기 검토 '},
#  {'subject': '파리올림픽 10m 공기권총 은메달리스트 김예지 선수 환영식'},
#  {'subject': '박형수  완벽한 캐릭터 소화력으로 선보일  폭군  속  조 과장 '},
#  {'subject': '질의에 답변하는 김예지 선수'},
#  {'subject': '최정 삼진→추신수 병살타→데뷔 첫 10SV 작성 ERA 10 80→9 56 시절에서 이렇게 달라지다니  히어로즈 최후의 1차지명 약속 지켰다'},
#  {'subject': '그날의 충돌 이후 효자 외인 떠나고  최고참도 시즌 아웃  내년에도 키움에서 볼 수 있나'},
#  {'subject': ' 2억원대  중고거래 사기 일당 항소심서 감형'},
#  {'subject': ' 경쟁률 70대 1  낙산사  나는 절로  주형환 저출산위 부위원장   나는 둘로  돼 돌아가길 '},
#  {'subject': '카카오게임즈   프렌즈팝  9주년 업데이트 사전등록 실시'},
#  {'subject': ' 유상임 아들 美 불법체류 당시 마리화나 의혹  野  과기장관 후보 사퇴 요구'},
#  {'subject': '구급차 불렀는데 출동 경찰 총격에 20대 한인여성 사망 종합 '},
#  {'subject': '임영웅  팬클럽  영웅바라기 서포터즈  파주시장애인복지관에 데뷔 8주년 기념 후원'},
#  {'subject': ' 절 소개팅  찾은 주형환  솔로가 절 와서 둘이 돼 돌아가길 '},
#  {'subject': '다이어트 근육강화제 등 해외직구식품 42%에  위해성분  검출'},
#  {'subject': ' 여자 400m 허들 최강자  매크로플린  세계기록 또 깼다'},
#  {'subject': ' 왕관 헤드폰  착용 아이유  9월 콘서트 메인포스터 공개'},
#  {'subject': '하윤경  산뜻한 비주얼  포토엔HD '},
#  {'subject': ' 리포트 브리핑 한온시스템   만조 滿潮 를 기다리며  목표가 6 500원   현대차증권'},
#  {'subject': ' 리포트 브리핑 한국타이어앤테크놀로지   누가 피크아웃 소리를 내었는가   목표가 68 000원   현대차증권'},
#  {'subject': '전북자치도 추석 특별 정책자금 850억원 규모 12일부터 지원'},
#  {'subject': '서울 중구  어린이 건강한 식생활 뮤지컬로 배워요'},
#  {'subject': '저고위 부위원장  청춘남녀 만남과 인연 지속하도록 돕겠다 '},
#  {'subject': '국가유산청   망건장  전영인씨 국가무형유산 보유자로 인정'},
#  {'subject': ' 사격銀  김예지  회견 중 실신후 회복 하루도 못 쉬었다 종합 '},
#  {'subject': '치료제 못 찾아 발만 동동  비수도권 더 심각 '},
#  {'subject': '입으로 즐기는  맛카오  미식 로드 5'},
#  {'subject': ' 마카오 A to Z  여행 미리보기'},
#  {'subject': ' 마카오 A to Z  조금 특별한 마카오 여행법'},
#  {'subject': '양산시  환경업무 근로자 대상  특별 안전교육  실시'},
#  {'subject': '상황 설명하는 심민 임실군수'},
#  {'subject': '커리 제임스  224㎝  농구 에펠탑  넘을까 올림픽 '},
#  {'subject': ' 리포트 브리핑 KT&G   2Q24 Review  담배 성장 견조  서프라이즈   목표가 120 000원   현대차증권'},
#  {'subject': ' 리포트 브리핑 고려아연   양호한 실적 지속  주주환원도 인상적  목표가 720 000원   현대차증권'},
#  {'subject': ' 리포트 브리핑 웹젠   P E 10배를 뚫으려면 신규 IP 필수  목표가 22 000원   현대차증권'},
#  {'subject': ' 리포트 브리핑 카카오   톡비즈 3rd 수익원 & AI 서비스가 온다  목표가 65 000원   현대차증권'},
#  {'subject': '고흥군  망고 재배 교육으로 신소득 작물 육성'},
#  {'subject': '고흥군  숯불구이 맛  여름 미식 여행  제안'},
#  {'subject': ' 생생경제  살 빼려고 제로 음료 골랐는데 다이어트에 도움 안 된다  왜 '},
#  {'subject': '셀트리온   짐펜트라  미국 26개 처방집 등재'},
#  {'subject': '실신한 사격 김예지 선수  의식 명료  대화도 가능 '},
#  {'subject': '한미  민관 에너지 협력 채널 구축 합의 무탄소에너지 활용 등 논의'},
#  {'subject': 'KT   2분기 실적 매출 4조5483억원 영업익 3588억원'},
#  {'subject': '코로나 입원환자 4주간 6배 급증 65세 이상이 65%'},
#  {'subject': '김예지 선수 기자회견 중 쓰러졌다 회복  병원 이송'},
#  {'subject': '병원으로 이송되는 김예지 선수'},
#  {'subject': ' 르포  이렇게 힘들었나 티메프 경안자금  개시 30분만에 100건 쇄도 '},
#  {'subject': '  14kg  한혜연  사진 찍을 맛나는 슬렌더 몸매  ★SHOT  '},
#  {'subject': '동메달 건 남북 복서 임애지 방철미  나란히 시상대에  파리올림픽 '},
#  {'subject': '연예인야구대회  치열 8강전 예고 입장 무료'},
#  {'subject': '주종혁   주터뷰 잘하고 오겠습니다   포토엔HD '},
#  {'subject': '내년  라이즈 체계  전국 시행 앞두고 현장 소통'},
#  {'subject': ' 가솔린 3736만원  기아  K8 계약 시작'},
#  {'subject': '이랜드 리테일  GOOD BUY  SUMMER FESTA 스페셜 행사'},
#  {'subject': ' HD현대 막내 조선소   국내 첫  액화CO₂운반선  건조 착수'},
#  {'subject': '대웅제약   역대 최대  2분기 영업익 496억원 전년比 37 1%↑'},
#  {'subject': ' 리포트 브리핑 클리오   2Q24 Review  견조한 해외 성장 지속  목표가 47 000원   현대차증권'},
#  {'subject': ' 리포트 브리핑 한국전력   2Q24 컨센서스 소폭 상회  여전히 목마른 전기요금 인상  목표가 30 000원   대신증권'},
#  {'subject': '10년전 뉴욕 한복판의 곰 사체 미스터리 대선 후보 케네디 짓이었다'},
#  {'subject': ' 심야괴담회  시즌4 김주령 괴스트 출연'},
#  {'subject': '사격 김예지  기자회견 도중 실신 회복 후 병원 이송 파리올림픽 '},
#  {'subject': '아이들극장에서 온 가족 함께 즐기는  종로 가족공연축제 '},
#  {'subject': ' 헤럴드포토  플랫폼H 경남가리비수협 업무협약 체결'},
#  {'subject': '클래식 선율 속 자유로움이 돋보이는 특별한 무대  8월 서울 예술의전당 콘서트 개최'},
#  {'subject': ' 마이데이터 전 분야 확산  규제개혁위 9일 심의'},
#  {'subject': ' 사진 하윤경  햇살 미소 날리며 인사 '},
#  {'subject': '방송인 홍현희 제이쓴 부부  아들 생일 맞아 1000만원 기부'},
#  {'subject': ' 리포트 브리핑 LG   하반기 자사주 소각 발표 기대  목표가 95 000원   대신증권'},
#  {'subject': ' 리포트 브리핑 삼화전기   2Q24 Review  흔들림 없이  목표가 100 000원   현대차증권'},
#  {'subject': ' 올림픽 별거 아니야  벌써 金 2개  태권도 분위기 좋다 오늘은 80kg 서건우 차례   올림픽 NOW '},
#  {'subject': 'K리그2 안산  제7대 사령탑에  시리우스  이관우 감독 선임'},
#  {'subject': ' 정영선  이 땅에 숨 쉬는 모든 것을 위하여   레드닷 디자인 어워드 최고상'},
#  {'subject': '주종혁   제가 수줍음이 많아서요   포토엔HD '},
#  {'subject': '세계랭킹 1위 女근대5종 성승민  펜싱 랭킹 라운드 8위 김선우는 11위'},
#  {'subject': ' 컨콜 네이버 대표  AI검색 서비스  큐  연내 모바일 출시 검토 '},
#  {'subject': 'SM엔터  직원 1인당 50주  스톡그랜트  지급 20억 규모'},
#  {'subject': ' 분명 범행을 자백했는데  30대 여성 성폭행 혐의로 체포된  日 엔도 후계자   갑자기 불기소처분'},
#  {'subject': '고령 금융소비자 불편에 응답한 삼성화재  콜센터 대리안내 제도 시행'},
#  {'subject': ' 마켓인  버튜버  콘텐츠 경제 요소 결합한 복합 엔터 산업으로 성장 '},
#  {'subject': ' 리포트 브리핑 LG   고요함 속의 outperform  목표가 100 000원   현대차증권'},
#  {'subject': ' 리포트 브리핑 시프트업   상저하고의 니케 & 중국 스팀 기대감 유효  Not Rated   현대차증권'},
#  {'subject': '김재중  16년 만에 지상파 음방 뚫었다 11일  인기가요  출격'},
#  {'subject': '183cm에 57kg  감량에 하루 발차기 1만번  세계랭커 압도  김유진의 초인적인 인내'},
#  {'subject': ' 리포트 브리핑 롯데케미칼   2Q24 review   경쟁사 대비 부진한 이익 회복세  목표가 125 000원   삼성증권'},
#  {'subject': '신안군  멸종위기 참달팽이 18마리 하태도에 방사'},
#  {'subject': ' 디케이앤디  52주 신고가 경신  최근 3일간 외국인 대량 순매수'},
#  {'subject': ' 중국서 유학왔어요  미중 갈등 속  캘리포니아주 판다  환대 '},
#  {'subject': '윤일상 프로듀싱 그룹 쓰리피스  RE100  홍보대사 발탁'},
#  {'subject': '함평군  소금 식초 된장 만들기  쌀 소비촉진 앞장 '},
#  {'subject': '성남시 판교수질복원센터 악취 개선 공사에 12억원 투입'},
#  {'subject': '관세청   티메프  추가 피해 방지 위해 수사 착수'},
#  {'subject': '경과원  창업혁신공간  투자 혹한기  단비 입주기업 매출 85% 증가'},
#  {'subject': ' 사격 스타  김예지  인터뷰 중 실신 후 회복→병원 후송  지병 없다  피로 긴장으로 추정   파리2024 '},
#  {'subject': '조희연  실질적 변화 위해 교권보호 3법 추가 제 개정 필요 '},
#  {'subject': '김경수 복권 소식에 野  환영  일각서  정치적 의도  우려도'},
#  {'subject': ' 흥민이형  현석이형이 추천해서 왔어요   오현규가 밝힌 헹크 이적 비하인드'},
#  {'subject': '주종혁  멋진 하트  포토엔HD '},
#  {'subject': '여자 복싱 은감바  난민팀 첫 메달 선사 75㎏급 동메달  2024 파리 '},
#  {'subject': '펄어비스  국가유산청과 맞손 경복궁에서 만나는  아침의 나라  서울 '},
#  {'subject': ' 젊고 강한 팀으로   K리그2 최하위  안산  이관우 감독 선임'},
#  {'subject': ' 사진 주종혁  포토타임은 쑥스러워요 '},
#  {'subject': ' 리포트 브리핑 SK바이오팜   가야할 방향으로 가장 먼저 가고 있다  목표가 130 000원   미래에셋증권'},
#  {'subject': ' 7 1 강진  후폭풍에 떠는 일본  100년만에 최악 대지진 오나 '},
#  {'subject': ' 이번 주말 폭염인데 치맥과 함께 올림픽 즐기세요   마지막 골든데이예요 '},
#  {'subject': ' 5살 연하♥  은가은  평소 이상형 들여다보니  박현호  만날만했네 '},
#  {'subject': ' 받아주는 병원 없었다  열사병에 쓰러진 기초생활수급자  끝내 사망'},
#  {'subject': '곽준빈x이동휘  한국 떠난다  난생처음 가는 곳  두려움  곽기사2 '},
#  {'subject': '안성시 산후조리비 지역화폐  경기 시 군에서 쓸 수 있다'},
#  {'subject': ' 리포트 브리핑 넷마블   찐써프  Origin까지 이 분위기로 쭉  목표가 90 000원   현대차증권'},
#  {'subject': '하윤수 부산교육감  인성영수캠프  2학기 자양분 되어 줄 것 '},
#  {'subject': '서울시  그린벨트 해제 지역에 신혼부부 주택 공급한다'},
#  {'subject': '현대차 숭실대   안전 전문가  만든다'},
#  {'subject': '펍지 모바일 국내 최강 가린다  2024 PMPS 시즌 2  10일 개막'},
#  {'subject': '광주시교육청  급식 근로자 안전보건 정기교육 실시'},
#  {'subject': '외국인 9개월째  바이 코리아  7월 증시서 22 4억달러 순유입'},
#  {'subject': ' 리포트 브리핑 넷마블   역대급 서프라이즈 시현  목표가 80 000원   미래에셋증권'},
#  {'subject': ' 리포트 브리핑 CJ ENM   보인다 티빙 흑전  느껴진다 izna 흥행  목표가 110 000원   현대차증권'},
#  {'subject': ' 리포트 브리핑 씨에스윈드   오프쇼어의 불확실성 제거  턴어라운드의 시작  목표가 78 000원   미래에셋증권'},
#  {'subject': ' 리포트 브리핑 LG이노텍   Decoupling하는 이유는 뭘까   목표가 318 000원   현대차증권'},
#  {'subject': ' 리포트 브리핑 인바디   미국 중심의 고성장 지속  목표가 37 000원   미래에셋증권'},
#  {'subject': '고창군 CCTV 통합관제센터  지명수배자 검거 큰 역할'},
#  {'subject': ' 올댓차이나  홍콩 증시  뉴욕 증시 강세에 매수 선행 상승 개장 H주 2 01%↑'},
#  {'subject': '한여름  체온 40도  열사병으로 숨진 기초생활수급자'},
#  {'subject': '아이슬란드서 미역국을  최우식은 좋겠네  서진이네2 '},
#  {'subject': ' 막내린 페페의 시대  호날두  원픽   41세 포르투갈  수비 전설  눈물의 현역 은퇴'},
#  {'subject': '흥민이 형 따라하는 거야  히샬리송  사우디 이적 거절 토트넘은 자금 마련 위해 매각 환영'},
#  {'subject': ' 윤이나 vs 방신실  장타보다 더 팽팽한 대결    장타 1위 때 벙커샷 2위  올해는  벙커 세이브 퀸  경쟁'},
#  {'subject': '세대를 넘어 함께 즐기는 트로트 뮤지컬 금천문화재단  트리아웃 '},
#  {'subject': '오세훈  저출생  절체절명 과제 그린벨트 풀어 주택 공급 '},
#  {'subject': '이정윤   KH그룹 전국실업유도선수권대회   78kg급 한판승  우승 '},
#  {'subject': '이원석  검사 탄핵  청문회 불출석  법치주의 훼손 '},
#  {'subject': '아이유 비즈 드레스 입고 여왕 비주얼  앙코르콘 기대 UP'},
#  {'subject': ' 안와 골절  수술까지 했던 카라 박규리  청순한 비주얼 되찾았네'},
#  {'subject': 'LG  위글위글과 2024년 컬래버 상품 출시 10일  서머 홀릭 이벤트  선수단 컬래버 유니폼 착용'},
#  {'subject': '서린상사   KZ트레이딩 으로 사명 변경  정체성 강화 '},
#  {'subject': '르세라핌  가창력 논란 딛고 10일  퍼펙트 나이트  리믹스 발매'},
#  {'subject': '자격 시비 끝에 치른 전북예총 회장 보궐선거 최무연씨 당선'},
#  {'subject': ' 사진 주종혁  상큼하게 엄지척 '},
#  {'subject': '경찰청이 제공한 실시간 교통 신호 정보 보행자와 함께 거닐 실외 이동로봇의 눈이 되다 '},
#  {'subject': '휴가 복귀 尹 광복절 특사 거부권 영수회담 등 현안 산적'},
#  {'subject': ' 1인당 1음료 주문  요구하자 음료 쏟아 중화권 진상 손님   손가락 욕 까지'},
#  {'subject': '손흥민 페이커 샤라웃   같이 밥먹고 싶은 스타 3인  거론'},
#  {'subject': '알고 지내던 여성 차에 감금하고 폭행한 50대 구속'},
#  {'subject': '마차도 실소 자아낸 168 5㎞ h 몸쪽 싱커  동상 세리머니  채프먼  PIT 마무리 맡을까'},
#  {'subject': ' 뮌헨  김민재 신뢰하는구나  獨 1티어 매체  무패우승  핵심 CB 포기 더 리흐트 이적과는 별개의 거래'},
#  {'subject': ' 아들 마약흡입  질병으로 포장   野  유상임 과기장관 후보자 사퇴 촉구'},
#  {'subject': '사격 김예지 의식 회복  피로 누적 긴장에 실신 추정 '},
#  {'subject': '주종혁   12시엔 주현영  최고  포토엔HD '},
#  {'subject': '아이유  월드투어 앙코르 콘서트 메인 포스터 공개'},
#  {'subject': '광양시  새내기 공무원 붙잡기 나서'},
#  {'subject': '이장호 군산대 총장 구속영장실질심사'},
#  {'subject': '현대차證  한국펀드평가와 퇴직연금 수익률 제고 MOU'},
#  {'subject': '메디톡스  톡신 필러 성장에 2분기 영업익 143억원 전년比 50%↑'},
#  {'subject': ' 잠정실적 메디톡스 2Q  매출 650억 전년동기 대비 26% 증가 영업이익률 상승전환  연결 '},
#  {'subject': ' 리포트 브리핑 씨에스윈드   일회성 수익이 크게 작용한 서프라이즈  목표가 75 000원   LS증권'},
#  {'subject': ' 리포트 브리핑 동아에스티   2Q24 Review  다가올 연구 성과들  목표가 83 000원   LS증권'},
#  {'subject': ' 리포트 브리핑 덴티움   지역적 다각화가 필요하다  목표가 135 000원   미래에셋증권'},
#  {'subject': ' 리포트 브리핑 한미약품   2Q24 Review  실적과 R&D 모두 순항 중  목표가 430 000원   LS증권'},
#  {'subject': '국내 최초 계곡형 아쿠아파크 탄생 지리적 접근성 뛰어나 수도권 충청 전북권서 이용객 몰려온다'},
#  {'subject': ' 올림픽  천만다행 사격 은메달 김예지  환영식서 실신했다가 의식 회복'},
#  {'subject': '임애지  비밀로 할게요  이 말에 무뚝뚝 北방철미도 웃었다 파리2024 '},
#  {'subject': ' 리포트 브리핑 현대리바트   상반기 호실적  하반기 B2B 둔화 방어가 관건  목표가 14 000원   미래에셋증권'},
#  {'subject': ' 리포트 브리핑 한국전력   하반기에도 기대되는 흑자 행진  목표가 27 000원   미래에셋증권'},
#  {'subject': ' 리포트 브리핑 미래에셋증권   투자자산 손실우려 경감 예상  목표가 9 800원   LS증권'},
#  {'subject': ' 리포트 브리핑 KT&G   2Q24 Review  역시 본업을 잘해야   목표가 110 000원   LS증권'},
#  {'subject': ' 리포트 브리핑 한전기술   2Q24 영업실적 호조   SMR 정부과제 기타수익  목표가 89 000원   LS증권'},
#  {'subject': ' 리포트 브리핑 롯데케미칼   어렵다 어려워  목표가 120 000원   LS증권'},
#  {'subject': ' 리포트 브리핑 HD현대   상장 자회사 주가와 수익성 개선의 수혜  목표가 110 000원   삼성증권'},
#  {'subject': ' 리포트 브리핑 씨에스윈드   2Q24 review  걱정이 기대감으로 바뀌는 순간  목표가 85 000원   삼성증권'},
#  {'subject': '조명래 창원시 제2부시장  검찰 송치 정치자금법 등 위반 혐의'},
#  {'subject': '지수연  뮤지컬  부치하난  출연 확정 전설→현실 오가는 캐릭터 변신 기대'},
#  {'subject': '유베이스 그룹 유진투자증권  공개매수 시장 혁신 MOU 체결'},
#  {'subject': '파라다이스  상반기 매출 5380억 전년비 15%↑  VIP가 실적 견인 '},
#  {'subject': ' 누구도 무섭지 않아  한국 태권도 필받았다 오늘은 80kg 서건우 출격 '},
#  {'subject': ' 포토  병원 이송되는 사격 김예지'},
#  {'subject': '여수산단서 50대 근로자 숨진 채 발견'},
#  {'subject': '왕관 쓴 아이유  콘서트 메인 포스터 공개 기대감↑  공식 '},
#  {'subject': '검찰  티몬 운영사업본부장 소환  티메프 미정산 사태  조사 본격화'},
#  {'subject': ' 너희들 카데나스 잘 모르잖아  코너는  태업 논란  동료 두둔했다 팬들은 갑론을박'},
#  {'subject': '주종혁   반갑습니다   포토엔HD '},
#  {'subject': '음식 배급소 줄 선 가자 지구 팔레스타인 어린이들'},
#  {'subject': ' 미운우리새끼  그리 결혼 고백에 초토화'},
#  {'subject': '이미주  ♥연하의 축구선수 남친 질투할 구썸남과 투샷'},
#  {'subject': ' 5살 연상연하  은가은♥박현호  트로트 커플 탄생  좋은 만남 이어가는 중 '},
#  {'subject': '美 대선 TV토론  내달 10일 확정  트럼프  해리스 상승세에 입장 변화 '},
#  {'subject': '이스라엘 군 대피 명령에 칸유니스 떠나는 가자 주민'},
#  {'subject': '황신혜 61세 핫한 패션  母 기가 막힌 꿈꿔→딸 진이 그 꿈 제가 살게요 '},
#  {'subject': ' 천의 얼굴  천우희  금융→패스트푸드까지 접수  광고 퀸  등극  러브콜 쇄도 '},
#  {'subject': '안주완 안선현 등  2024 GROUND N K리그 U15&14 챔피언십 서 주목할 만한 선수는 '},
#  {'subject': '허형규  현 소속사 키이스트와 재계약 체결'},
#  {'subject': '일본 지진으로 무너진 가정집'},
#  {'subject': '지진으로 쓰러진 일본 식당 주방 비품들'},
#  {'subject': '성남문화재단  롯데백화점 분당점과 업무협약 체결'},
#  {'subject': ' 리포트 브리핑 한온시스템   점점 낮아지는 눈높이  목표가 6 000원   LS증권'},
#  {'subject': '20대 한인 여성  미국서 또 경찰 총격에 사망'},
#  {'subject': '천우희  금융→뷰티까지  천의 얼굴 의 광고 활약'},
#  {'subject': '한국 태권도  이틀 연속 금빛 포효 김유진  세계 1 2 4 5위 모두 꺾는 대이변'},
#  {'subject': '부산시교육청  인성영수캠프 수료식 개최'},
#  {'subject': '주종혁   12시엔 주현영 주터뷰 코너  참석  포토엔HD '},
#  {'subject': '트레저  멋진 조각보물들   ★영상 '},
#  {'subject': '한 건이라도 더 결혼 길일에 공무원  연장근무 '},
#  {'subject': '안성시  제5기 시민옴부즈만 뽑는다 30일까지 9명 모집'},
#  {'subject': ' 리포트 브리핑 스튜디오드래곤   최선의 방어  목표가 55 000원   삼성증권'},
#  {'subject': ' 리포트 브리핑 SK바이오팜   Xcopri 판매 확대로 이익 성장 모멘텀 강화  목표가 120 000원   삼성증권'},
#  {'subject': '기자회견 중 쓰러진 김예지 선수  현재 의식 회복  치료 중 '},
#  {'subject': ' 빅토리  박세완  볼살 때문에 7kg 찌워 어린 친구들  소중함 몰라   엑 s 인터뷰 '},
#  {'subject': ' 사격 銀  김예지  기자회견 중 쓰려졌다 다행히 곧바로 회복'},
#  {'subject': '전남대 연구팀  하와이서 독립운동가 묘지 1200기 발굴 오는 13 14일 공개'},
#  {'subject': '사격 김예지  기자회견 도중 쓰러졌다 회복'},
#  {'subject': '밀양시 반응형 미디어아트  여름밤의 특별한 추억 선사'},
#  {'subject': ' 추신수 전 동료  임시직으로 앉혀 놓더니  대놓고  정식 감독 후보는 아니다  CHW'},
#  {'subject': ' 양육비 준 돈으로 프랑스 놀러 간 전처 아들은 3년간 안 데려갔다 '},
#  {'subject': '이현재 하남시장  어르신들의 건강 위해 AI 건강관리 로봇 하남이 도입'},
#  {'subject': '유니스  기아타이거즈 승리 요정 첫 시구 시타'},
#  {'subject': ' 리포트 브리핑 넷마블   신작 흥행으로 이익 서프라이즈  목표가 81 000원   삼성증권'},
#  {'subject': ' 티메프 사태  큐텐 계열사로 확산 인력 구조조정 돌입'},
#  {'subject': ' 리포트 브리핑 덴티움   장비 재고자산 평가손실 발생하며 컨센서스 하회  목표가 150 000원   삼성증권'},
#  {'subject': '새벽  사상 4명  구로역 출근길  일어나선 안 될 일  침통'},
#  {'subject': '경기도일자리재단   여성 취창업 활성화 라운드 테이블  개최'},
#  {'subject': '트로트도 연상연하 커플 탄생 은가은 박현호 열애 시작'},
#  {'subject': 'KT 2분기 연속  4조 매출   상반기 영업이익 1조 달성'},
#  {'subject': '넥슨   FC 프로 챔피언스 컵  8월 19일 개최 한국 대표팀 출전'},
#  {'subject': '대웅제약  2분기 영업익 496억원 전년 동기 比 37 1%↑'},
#  {'subject': '여수시  읍면동 주민센터에  섬섬샘물  비치 온열질환 예방'},
#  {'subject': '김경수 복권에 술렁이는 野 친문계 결집 구심점 될까'},
#  {'subject': ' 리포트 브리핑 넷마블   좋은 실적 vs  빗겨간 컨셉  목표가 58 000원   메리츠증권'},
#  {'subject': ' 리포트 브리핑 CJ ENM   확실한 존재감을 발휘  목표가 103 000원   삼성증권'},
#  {'subject': ' 리포트 브리핑 넥슨게임즈   K 게임의  웨스턴 드림  대장주  Not Rated   메리츠증권'},
#  {'subject': '시흥시  고용노동부 일자리 대상  우수상  2년 연속 입상'},
#  {'subject': ' 한복의 멋 '},
#  {'subject': ' 사진 하윤경  봄날의 햇살 같은 그녀 '},
#  {'subject': ' 스캔들 → 굿파트너  오늘 9일  결방 파리 올림픽 경기 여파'},
#  {'subject': ' 북적이는 한복상점 '},
#  {'subject': '주종혁  힙하게 출근  포토엔HD '},
#  {'subject': '팔 깁스 한  딸 여서정 에 곧장 달려간  아버지 여홍철   김성락의 Knock '},
#  {'subject': ' 북적이는 한복상점 '},
#  {'subject': '태권도 김유진   세계 1위  고비 넘고 결승행 57kg 은메달 확보'},
#  {'subject': '의왕시  2024년도 상반기 특별징수대책  평가 최우수'},
#  {'subject': '2024 한복상점 찾은 관람객들'},
#  {'subject': ' 생생경제   AI 거품론 에  팔아야하나   여전히 유망한 이유는 '},
#  {'subject': '토트넘의 손흥민 파트너 될  New No 9  영입  히샬리송 거취와 관련 없다'},
#  {'subject': ' 안세영 눈높이가 손흥민 김연아급  협회 발언  역풍   2024 파리올림픽 '},
#  {'subject': ' 리포트 브리핑 SK바이오팜   2Q24 Review  레버리지 효과 이제 시작  목표가 120 000원   메리츠증권'},
#  {'subject': '이기흥 체육회장  안세영  하고픈 말 많아도 표현 부적절 '},
#  {'subject': ' 북적이는 한복상점 '},
#  {'subject': ' 인사  대구교육청 유치원 초등 특수 '},
#  {'subject': '광주광역시  무등산 일대서 실험 위주  지오스쿨 여름학기  운영'},
#  {'subject': ' 컨콜 네이버  A홀딩스  라인야후 지분 약 1 2% 줄인다 日 상장 유지 조건 충족 '},
#  {'subject': '이원석 검찰총장 김영철 검사 청문회 불출석  사법을 정쟁으로 끌어들여 '},
#  {'subject': ' 인사  대구교육청 중등 '},
#  {'subject': ' 리포트 브리핑 한국타이어앤테크놀로지   2Q24 Review  글로벌 최상의 수익성  최하의 Valuation  목표가 54 000원   삼성증권'},
#  {'subject': ' 단아한 한복 '},
#  {'subject': ' 굿파트너  한재이  휴방 달래는 미소'},
#  {'subject': ' 다양한 한복의 미 '},
#  {'subject': '2024 한복상점 관람하는 방문객들'},
#  {'subject': '2024 한복상점 찾은 관람객들'},
#  {'subject': '2024 한복상점  요즘 한복 '},
#  {'subject': '2024 한복상점 찾은 관람객들'},
#  {'subject': ' 다양한 한복의 미 '},
#  {'subject': ' 수지 혜리 100번 찍어도 짜증 안 내   빅토리  박세완이 본 연기돌  인터뷰③ '},
#  {'subject': ' 다양한 한복의 미 '},
#  {'subject': '국민의힘  김경수 복권 전망에  여야 협치의 중요한 계기될 것 '},
#  {'subject': '안정환  MBC 올림픽 축구 결승 중계방송 컴백 태권도는 이대훈'},
#  {'subject': '횡단보도 건너기 성공한 이동로봇  교통신호 정확히 인식 '},
#  {'subject': ' 혜리와 쌓은 부담감 터졌다  박세완   빅토리  시사회 눈물 이유  인터뷰② '},
#  {'subject': ' 멋스러운 한복 '},
#  {'subject': ' 리포트 브리핑 펄어비스   붉은사막  높아진 눈높이 넘어설까   목표가 33 000원   삼성증권'},
#  {'subject': ' 리포트 브리핑 카카오   혁신보다 개선을 선택  목표가 42 000원   삼성증권'},
#  {'subject': '서울 구로역서 작업 차량 사고 3명 사상'},
#  {'subject': '야당 소집  방송장악  청문회 개최 이진숙 방통위원장 불출석'},
#  {'subject': '韓육상 클라이밍 자존심 걸고   우상혁 서채현  사상 최초  메달 앞으로 올림픽 '},
#  {'subject': 'NCT DREAM  영어 싱글  Rains in Heaven  8월 23일 오후 1시 발매'},
#  {'subject': '하윤경  깜찍한 볼하트  포토엔HD '},
#  {'subject': '코로나19 입원 환자 3주 만에 6배↑  8월 말까지 증가 '},
#  {'subject': '적게 일하고 재테크하는  황제  vs 매일 알바해도 허덕이는  유목민 '},
#  {'subject': ' 빅토리  박세완  억지로 7kg 찌워  매일 초코라떼 라면 먹고 잤다   인터뷰① '},
#  {'subject': '의왕도시공사  의왕테니스장 9월까지 무료 운영'},
#  {'subject': '김경수  복권 가능성에 민주당  환영할 일 숨겨진 의도 있나 '},
#  {'subject': '노브레인 이성우  러블리즈 생일 때마다 축하송 보내 '},
#  {'subject': '이상일 용인시장  파리 올림픽 다이빙 경기장 찾아 벤치마킹'},
#  {'subject': ' 장중수급포착  HD현대일렉트릭  외국인 기관 동시 순매수 주가  2 97%'},
#  {'subject': ' 장중수급포착  HD현대마린솔루션  외국인 기관 동시 순매수 주가  9 80%'},
#  {'subject': ' 장중수급포착  파두  외국인 기관 동시 순매수 주가  3 17%'},
#  {'subject': ' 장중수급포착  티씨케이  외국인 기관 동시 순매수 주가  4 76%'},
#  {'subject': '하윤경  핑크빛 하트  포토엔HD '},
#  {'subject': '전남교육청  청렴 감사 역량 강화 연수 진행'},
#  {'subject': ' 19일 컴백  SF9  청량함 속 은은한 섹시美 미니 14집 콘셉트 눈길'},
#  {'subject': '장수군  귀농귀촌인 한마음대회  개최'},
#  {'subject': '광주자치경찰  전남대 원룸촌 범죄예방 환경개선'},
#  {'subject': '울산시  침수위험 높은 지하차도 진입차단시설 설치'},
#  {'subject': '보성 율포항  국가어항 신규지정 예비대상항 선정'},
#  {'subject': '휴온스  자회사 실적부진에 2분기 영업익 93억원 전년比 48%↓'},
#  {'subject': '국가유산청  서울어린이대공원 수달관 개관 기념 특별전 8 12  8 25  '},
#  {'subject': '  전기차화재  스프링클러 미작동 원인은 밸브 임의조작 '},
#  {'subject': '코로나19 입원환자 급증 추세 정부  대응방안 점검'},
#  {'subject': ' 인간 창작물 vs AI 활용 작품  영상 공모전 AI 작품 승리'},
#  {'subject': ' 한동훈 제3자 특검법 내놔라  野 공세에 고심 깊어지는 韓'},
#  {'subject': '아프다는 카데나스 향한 일부 삼성팬 SNS 테러   응원했던 사람들이 어떻게  외인 동료는 실망감 표출'},
#  {'subject': '하루도 안돼 뒤집힌 北  갤럭시 수령 논란  IOC 입장 번복에 혼선'},
#  {'subject': '서울시  반포 예의주시 중 토지거래허가구역 지정할 수 있어 '},
#  {'subject': '이찬원   불후의 명곡  소설  토지  완간 30주년 기념 공연 출격  박경리  기억하고 노래하다 '},
#  {'subject': ' 한끗차이  북쪽 보내도 일자리 꿰찰 똘똘이 찬또위키 이찬원  뭔데 얘  뭐하는 앤데 똑똑해 '},
#  {'subject': ' 이것  바꿨더니 1030 사용자 폭증 네이버  반전  쓴 비결'},
#  {'subject': '약속 지킨 전현무  대망의  역도 중계  11일 출격  시청률 1위 기대   사당귀  '},
#  {'subject': ' 말복 더위는 가라  SPC 배스킨라빈스  최대 6000원 할인 이벤트'},
#  {'subject': '안성시   안성여행 스마트폰 사진공모전  10월25일까지'},
#  {'subject': '강진군  농업인 비닐하우스 설치비 지원'},
#  {'subject': ' 전차선 점검하던 높은 작업대를 옆 선로 점검차가 부딪힌 듯 '},
#  {'subject': ' 컷오프 경선패  안병길 전봉민 낙하산 논란에도  침묵 '},
#  {'subject': ' 장중수급포착  에스앤디  외국인 기관 동시 순매수 주가  12 57%'},
#  {'subject': ' 장중수급포착  프로이천  외국인 기관 동시 순매수 주가  10 53%'},
#  {'subject': 'BNK자산운용  주식형 펀드 중장기 수익률 국내 1위'},
#  {'subject': '귄도안 하피냐 파티 이적 시장에 바르셀로나 에이스 쏟아진다'},
#  {'subject': '카타르 국왕 환영하는 에르도안 튀르키예 대통령'},
#  {'subject': ' 오늘의인사   국세청 외 8월 9일자'},
#  {'subject': '회담하는 에르도안 튀르키예 대통령과 카타르 국왕'},
#  {'subject': '장수군   2024 귀농귀촌 한마음대회  개최'},
#  {'subject': ' 빅토리  박세완  춤 잘 춘다고요  연기 칭찬보다 좋아요  인터뷰① '},
#  {'subject': '관악구  전국 지방자치단체 일자리대상 3년 연속 수상'},
#  {'subject': '52개 미술 단체   이건희 기증관  포함 국립20C 근대 미술관 설립  촉구'},
#  {'subject': ' 특징주  한국비엔씨  지속형 비만치료제 위고비 계열 후보물질 도출  효과 확인  소식에 강세'},
#  {'subject': '검찰총장  탄핵대상 검사 모두 청문회 불출석  위법한 절차 '},
#  {'subject': '영화  추격자  실존 인물  마약판매 혐의로 검거'},
#  {'subject': '쌍방울 비비안  영양군청에 4400만원 상당 물품 기부'},
#  {'subject': ' 장중수급포착  동진쎄미켐  외국인 기관 동시 순매수 주가  5 75%'},
#  {'subject': ' 영상구성  중앙고속도로 탱크로리 화재 2 400만원 피해 外'},
#  {'subject': ' 식민지배 사죄  미쓰비시 항의방문 대학생 20명 유죄 확정'},
#  {'subject': '카타르 국왕과 악수하는 에르도안 튀르키예 대통령'},
#  {'subject': ' 성추행 3년 징계  피겨 이해인 무너뜨린 거짓말 父  바로잡고 싶다 '},
#  {'subject': '카드  신곡  Tell My Momma  음원&노랫말 일부 공개'},
#  {'subject': ' 전기 쇠꼬챙이로 개 도살  경기도특사경 현장급습 농장주 검거'},
#  {'subject': ' 16년 만에 체급 金  김유진   한 번에 만 번씩 발차기했다   파리올림픽 '},
#  {'subject': '양지은  8일 부친상 신장 나눈 父와 이별'},
#  {'subject': '올림픽 사격 은메달 김예지  기자회견 중 쓰러졌다 회복'},
#  {'subject': ' 장중수급포착  모나용평  외국인 기관 동시 순매수 주가  6 65%'},
#  {'subject': '김경수 전 경남도지사   광복절 특사  복권 대상 포함'},
#  {'subject': ' 민생법안  합의에도 곳곳 대치  김경수 복권 여부  촉각'},
#  {'subject': '경찰  최재영 목사 공직선거법 위반 혐의로 송치 결정'},
#  {'subject': ' 사격 銀  김예지 의식 잃었다  응급조치 후 10분 만에 회복  긴장감과 피로가 원인  파리 2024 '},
#  {'subject': '네이버  사상 최대 매출 이익  3 5년 두 자릿수 성장세 확신  종합 '},
#  {'subject': '대구동부소방서  119소방정책 콘퍼런스 최우수상'},
#  {'subject': ' 새내기 공무원 붙잡아라  광양시   특별휴가  신설 확대'},
#  {'subject': ' 장중수급포착  대우건설  외국인 기관 동시 순매수 주가  2 45%'},
#  {'subject': '박진만 감독  왜 3년차 거포  최고 3루수 될 것  확신했나 김영웅 2018년 러프 이후 첫 삼성 30홈런 타자 도전'},
#  {'subject': ' 우면 세곡 방이  신규택지 거론 벌써  들썩 '},
#  {'subject': ' 美무역적자국  한국이 일본 처음 추월했다 트럼프 당선땐 리스크'},
#  {'subject': ' 장중수급포착  한화솔루션  외국인 기관 동시 순매수 주가  5 51%'},
#  {'subject': ' 장중수급포착  대주전자재료  외국인 기관 동시 순매수 주가  9 35%'},
#  {'subject': '오세훈  그린벨트 해제   훼손지  한정  신혼부부 주택 확대 종합 '},
#  {'subject': ' K 드라마 신드롬  김영대  편의점 알바생 캐릭터 200% 착붙  손해 보기 싫어서 '},
#  {'subject': '은가은  5살 연하 ♥박현호와 열애 중  좋은 만남 이어가는 중   공식입장 '},
#  {'subject': ' G 브리핑  엔미디어플랫폼   GETO PC방 핫타임 이벤트  진행'},
#  {'subject': '은가은♥박현호  트로트 연상연하 커플 탄생    누나 동생에서 연인으로 '},
#  {'subject': '여름철 농축수산물 수급 안정 총력 배추 일평균 400톤까지 공급'},
#  {'subject': '주종혁 Joo Jong hyuk   자신있게 엄지 척    O  STAR 숏폼 '},
#  {'subject': '광주 동구  지방세 고지서 활용 위기가구 적극 발굴 나서'},
#  {'subject': '경남서 쌀값 인상 요구 논 갈아엎어'},
#  {'subject': '생애주기별 맞춤 프로그램 부산 사하구  생애드림 프로젝트  운영'},
#  {'subject': '우크라  사흘째  최대 10㎞  러 본토 진격  러  전쟁 느껴봐라 '},
#  {'subject': '퀸 그 자체   아이유  9월 단콘 메인 포스터 공개'},
#  {'subject': 'NCT 드림  23일  레인스 인 해븐  발매  따뜻한 위로 메시지 전한다 '},
#  {'subject': ' 167cm 54kg  안혜경 비주얼 근황  늙지도 않고  사랑 받아 예뻐졌나  핫한 반응'},
#  {'subject': '16년 만에 붙잡힌 시흥 슈퍼마켓 강도살인 40대 구속기소'},
#  {'subject': ' 안정환♥  이혜원  뉴욕대 엘리트 딸과 눈부신 투샷  우월 유전자 '},
#  {'subject': '프리지아 얼마나 마른거야  밀착 원피스 허리가 남네'},
#  {'subject': '유이→진서연  女배우 최초 철인 3종 경기  핫한 스포츠 열기  잇는다  무쇠소녀단 '},
#  {'subject': '대경권 이랜드리테일    GOOD BUY SUMMER FESTA  스페셜 행사 돌입'},
#  {'subject': '남원시   학교복합시설 공모사업  선정  지리산 체육센터  건립'},
#  {'subject': ' 장중수급포착  삼성카드  외국인 기관 동시 순매수 주가  1 72%'},
#  {'subject': ' 장중수급포착  SK바이오팜  외국인 기관 동시 순매수 주가  3 23%'},
#  {'subject': '폭염 잊으며 숲에서  힐링  산림욕장 찾은 피서객들'},
#  {'subject': ' 체험기   엄마와 딸  64쌍 모여  찰칵  CJ온스타일 VVIP행사 가보니  언박싱 '},
#  {'subject': ' 북극곰  스피박  티부라 복수다 '},
#  {'subject': '블핑 리사  바비인형이 여기 있네 재벌 남친이 반한 비주얼  ★SHOT  '},
#  {'subject': '韓 근대5종 순조로운 출발 전웅태  펜싱 랭킹 라운드 4위→도쿄 때보다 낫다  파리2024 '},
#  {'subject': '윤산하가 직접 밝힌  가족X멜로  관전 포인트  잊고 지냈던 가족의 소중함 '},
#  {'subject': '박세완  빠져드는 눈망울  ★포토 '},
#  {'subject': '쌀값 인상 요구'},
#  {'subject': '물병 들고 있던 美 20대 한인 여성  경찰 총격에 사망'},
#  {'subject': '한국비엔씨  지속형 비만치료제 후보물질 도출해 효과 확인 '},
#  {'subject': '거창군  여름철 모기매개 감염병 예방  방역 강화'},
#  {'subject': '실신 직전의 김예지'},
#  {'subject': ' 사진 하윤경  손인사도 러블리하게 '},
#  {'subject': ' 장중수급포착  LS  외국인 기관 동시 순매수 주가  3 70%'},
#  {'subject': ' 장중수급포착  덕산네오룩스  외국인 기관 동시 순매수 주가  2 78%'},
#  {'subject': '민주  숨진 권익위 국장  尹정권 수사외압 피해자 진상규명 '},
#  {'subject': ' 장중수급포착  삼성물산  외국인 기관 동시 순매수 주가  3 04%'},
#  {'subject': ' 물놀이가 최고  경주 워터파크 피서 인파'},
#  {'subject': '제주도  저염분수  대응 1단계 발령 서부 해역 9㎞ 지점 유입'},
#  {'subject': '박세완  압도적 미모  ★포토 '},
#  {'subject': '올림픽 은메달 김예지  기자회견 중 쓰러졌다 회복'},
#  {'subject': '홈 어드밴티지 사라지자  金20  목표 일본  한국에 밀렸다 파리올림픽 '},
#  {'subject': '박세완  매력적인 패션센스  ★포토 '},
#  {'subject': ' 이란  대이스라엘 보복 규모 방식 재고할 수도 '},
#  {'subject': ' 글로벌 정조준  화해  김경일 신임 대표 선임   각자 대표 체제 전환'},
#  {'subject': 'PGA 윈덤챔피언십 악천후로 1R 연기 허리케인 영향'},
#  {'subject': '野 과방위원  유상임 아들 마리화나 의혹 자진 사퇴하라 '},
#  {'subject': '방시혁  BJ 과즙세연과 美 거리에서 포착  LA서 우연히 만나 가이드만  해명'},
#  {'subject': '나주시  착한가격업소 20개소 신규 모집 '},
#  {'subject': '美서 팔린 삼성전자 전기레인지 112만대 리콜 조치'},
#  {'subject': ' 김성태  주가조작 위해 대북사업  檢 내부 수사보고서 공개'},
#  {'subject': '경남서 쌀값 인상 요구 논 갈아엎어'},
#  {'subject': ' 미우새  그리  짝사랑 그녀  군대 기다려주면 결혼할 것 '},
#  {'subject': '아프리카 보건당국  원숭이두창 확산에  보건비상사태 선포할 수도 '},
#  {'subject': ' 주차 요금 결제 편하게  여주시   사전무인정산기  설지'},
#  {'subject': ' 장중수급포착  엔씨소프트  외국인 기관 동시 순매수 주가  1 50%'},
#  {'subject': ' 장중수급포착  현대차  외국인 기관 동시 순매수 주가  3 38%'},
#  {'subject': '폭염 온열질환자 누적 2 004명 가축 폐사에 녹조도'},
#  {'subject': ' 더 존3  초특급 게스트 뜬다 차태현→샤이니 키   존버즈  찐친 출격'},
#  {'subject': '대구농업기술센터  민관 협력 농업인 온열질환 예방 캠페인 전개'},
#  {'subject': ' 선업튀 빌런  허형규  키이스트와 재계약 체결  공식 '},
#  {'subject': '간 해독효과 탁월 산림청  8월 임산물 에 헛개나무 선정'},
#  {'subject': '은감바  난민팀 최초 시상대 오른다 여자복싱 75㎏급 동메달 올림픽 '},
#  {'subject': ' 장중수급포착  헥토파이낸셜  외국인 기관 동시 순매수 주가  4 62%'},
#  {'subject': '남원시  100세 이상 어르신에 50만원 상당 장수축하물품 지급'},
#  {'subject': ' 빅토리  박세완   춤 잘 춘다 는 댓글  연기 칭찬보다 뿌듯   엑 s 인터뷰 '},
#  {'subject': '순창군  조선대와  농촌사랑 동행순창  협약'},
#  {'subject': '검찰   티메프  수사 박차 권도완 티몬 운영사업본부장 조사'},
#  {'subject': '오영주 중기장관  티메프 피해 소상공인에 유동성 공급 제일 중요 '},
#  {'subject': '영등포구  지자체 일자리 대상  우수상 수상'},
#  {'subject': '한국사회복지협의회 베베쿡  취약계층에 6100만 원 상당 영유아 이유식 기부'},
#  {'subject': ' 中 부양 기대감 사라져  철광석 100달러 붕괴되나'},
#  {'subject': '3년 만에 돌아온 기아 K8 최신 디자인 성능 적용'},
#  {'subject': '진지하게 답변하는 김예지 선수'},
#  {'subject': '심민 임실군수와 기념촬영 하는 김예지 선수'},
#  {'subject': '동부건설  3155억원 규모  강릉 제진 철도건설 8공구  수주'},
#  {'subject': '대전 문지동 초등학교 교실서 화재 천장형 선풍기 과열 추정'},
#  {'subject': ' 음주  슈가→ 女BJ 동행  방시혁 하이브  바람잘 날 없네  SC이슈 '},
#  {'subject': '경남서 쌀값 인상 요구 논 갈아엎어'},
#  {'subject': ' 단독   구제역 황금폰  미성년착취물 있었다   유포자 피고발'},
#  {'subject': '코로나19 입원환자 한달 새 9배  껑충  정부  8월 말까지 유행 지속될 듯 '},
#  {'subject': '김예지 선수 만난 관계자들 사진 한장 찰칵 '},
#  {'subject': '경남서 쌀값 인상 요구 논 갈아엎어'},
#  {'subject': '꽃다발 든 김예지 선수'},
#  {'subject': '경남 의령서 쌀값 인상 요구 논 갈아엎어'},
#  {'subject': ' 콘텐츠 핫&뉴   오디션  한정판 여름 액세서리 획득 이벤트'},
#  {'subject': '수달 장수하늘소 자연유산 만나볼까'},
#  {'subject': '김남길 정우성   리볼버  위해 나섰다 GV 참석 확정'},
#  {'subject': '밝은 표정으로 질의 답변하는 김예지 선수'},
#  {'subject': ' 재미교포♥  클라라  중국 사로잡은 명품 몸매 독보적 분위기 눈길'},
#  {'subject': '뿔난 농심'},
#  {'subject': '검찰총장 탄핵 대상 검사 모두 청문회 불출석 입장'},
#  {'subject': '현대차 기아 자율주행 배송로봇  도심 횡단보도 실증 주행 성공  달이 딜리버리  전국 누빈다 '},
#  {'subject': '박세완  완벽 미모  ★포토 '},
#  {'subject': '하윤경  Ha Yoon Kyung   봄날의 햇살처럼 화사해   O  STAR 숏폼 '},
#  {'subject': ' 장중수급포착  피에스케이  외국인 기관 동시 순매수 주가  7 89%'},
#  {'subject': ' 장중수급포착  DB하이텍  외국인 기관 동시 순매수 주가  3 68%'},
#  {'subject': '김영록 전남지사  인요한 최고위원에게 현안 건의'},
#  {'subject': '오세훈  저출생  절체절명 과제 그린벨트 풀어 주택공급  종합 '},
#  {'subject': '서울지역 국민의힘 국회의원 서울시교육청 교육정책 협의회'},
#  {'subject': ' MD앱테크  8월 9일 캐시워크 돈버는 퀴즈정답 엔뚜마노 칼세트 '},
#  {'subject': '대구교육청  교육공무원 442명 인사 단행'},
#  {'subject': '합천군  고물가 잡는  착한가격업소  추가 모집'},
#  {'subject': ' 사진 하윤경  단아한 자태 '},
#  {'subject': ' 장중수급포착  포스코DX  외국인 기관 동시 순매수 주가  3 09%'},
#  {'subject': '서울지역 국민의힘 국회의원 만난 조희연 시교육감'},
#  {'subject': ' 장중수급포착  에코프로비엠  외국인 기관 동시 순매수 주가  7 09%'},
#  {'subject': ' 장중수급포착  클래시스  외국인 기관 동시 순매수 주가  4 26%'},
#  {'subject': '벤츠코리아  전기차 화재 대응 미숙  분통   BMW와 비교되네 '},
#  {'subject': '현대차 기아 자율주행 배송로봇 도심 횡단보도 실증 주행 성공'},
#  {'subject': ' 장중수급포착  잉글우드랩  외국인 기관 동시 순매수 주가  8 15%'},
#  {'subject': ' 장중수급포착  원익IPS  외국인 기관 동시 순매수 주가  2 04%'},
#  {'subject': ' 장중수급포착  하나머티리얼즈  외국인 기관 동시 순매수 주가  7 49%'},
#  {'subject': '주말 더 뜨거워진다 올여름 무더위 이달 하순까지'},
#  {'subject': ' 노련  트럼프 vs  논리  해리스 첫  TV 大戰 '},
#  {'subject': '유누스 방글라 최고 고문   법과 질서 유지가 첫 과제 '},
#  {'subject': '서울지역 국민의힘 국회의원 서울시교육청 교육정책 협의회'},
#  {'subject': '국민의힘 서울시교육청 교육정책협의회'},
#  {'subject': '멸종위기 Ⅱ급  참달팽이  18마리  신안 흑산 하태도 방사'},
#  {'subject': '김유진 13번째  깜짝 金  대한민국 역대 최다 金  카운트다운  2024 파리올림픽 '},
#  {'subject': '취임 선서하는 유누스 방글라 최고 고문과 대통령'},
#  {'subject': '서울지역 국민의힘 국회의원 서울시교육청 교육정책 협의회'},
#  {'subject': ' 셀럽이슈 블랙핑크  오늘 9일  11개월 만 완전체로 공식석상  토크 진행 NO '},
#  {'subject': '코로나19 재유행  진단키트 판매량 증가'},
#  {'subject': '코로나19 재유행  진단키트 판매량 증가'},
#  {'subject': '늘어나는 코로나19 환자  진단키트 판매량 증가'},
#  {'subject': '학부모 과잉 개입에 법정 가는  애들 싸움 '},
#  {'subject': '해리스   트럼프 내달 10일 첫 TV토론'},
#  {'subject': '코로나19 재유행  진단키트 판매량 증가'},
#  {'subject': '과도정부 출범식 참석한 유누스 방글라 최고 고문'},
#  {'subject': '코로나19 재확산 조짐에 자가진단키트 수요도 급증'},
#  {'subject': '대법  SK텔레콤  전자처방전   개인정보보호법 의료법 위반 아냐 '},
#  {'subject': '뿔난 농심'},
#  {'subject': '늘어나는 코로나19 환자  진단키트 판매량 증가'},
#  {'subject': '견우와 직녀 만난 날 맞아 혼인신고 건수 올리기  총력 '},
#  {'subject': '과도정부 최고 고문 취임 선서하는 방글라의 유누스'},
#  {'subject': ' 속보  사격 은메달 김예지  기자회견 중 실신  피로 누적 '},
#  {'subject': '늘어나는 코로나19 환자  진단키트 판매량 증가'},
#  {'subject': '트레저 요시  만찢남 비주얼  ★포토 '},
#  {'subject': '논 갈아엎는 농민'},
#  {'subject': '숯 향 그윽한 고흥에서 맛있는 휴가를 '},
#  {'subject': '신한은행   10년 주기형 주담대  금리는 연 3 38 5 29%'},
#  {'subject': '검찰  티몬 운영사업본부장 참고인 조사 티메프 수사 속도'},
#  {'subject': '코로나19 재확산 조짐에 자가진단키트 수요도 급증'},
#  {'subject': ' 사진 주종혁  미소 활짝 '},
#  {'subject': '농민 쌀값 인상 촉구'},
#  {'subject': '사격 김예지 기자회견 중 실신 후 회복 정밀검사 예정 종합 '},
#  {'subject': ' 2024 대한민국무용대상  9개 단체  치열한 경연 펼쳐'},
#  {'subject': '채드 멘데스  UFC 페더급 역대 최강은 알도 > 맥그리거  알도는 짐승 '},
#  {'subject': '공기권총 은메달리스트 김예지  기자회견 중 실신 현장서 회복 후 병원 이송'},
#  {'subject': ' 사격 은메달  김예지  경련 후 실신  현장서 회복 '},
#  {'subject': '스키니랩  오는 14일까지 강원도 양양에 팝업 부스 오픈'},
#  {'subject': '숨진 권익위 간부 사망 사건  부검 없이 종결키로'},
#  {'subject': '  67%  자존심 구긴 국민주 꿈틀  네이버 오르는데 카카오는  울상 '},
#  {'subject': 'DL이앤씨  안전관리자 직무교육 실시 전원 CPR 수료증 취득'},
#  {'subject': '코로나19 재확산 조짐에 자가진단키트 수요도 급증'},
#  {'subject': ' 파리올림픽 2024  김유진  여자 57㎏급 정상 강자들 다 정리하고 金 수확'},
#  {'subject': '2025년 도입  고교학점제  이렇게 대비 당부'},
#  {'subject': '대만의 對中 수출 갈수록 감소 7월엔 對美 수출액과  비슷 '},
#  {'subject': '與 고동진   티메프 사태 방지법  발의  10일 내 정산 '},
#  {'subject': '與  野 방송장악 청문회 강행  방통위 무너뜨리겠단 뜻 '},
#  {'subject': '민주  尹정권 친일바이러스 전성시대 독립기념관장 임명 취소해야 '},
#  {'subject': ' 올댓차이나  中 증시  기술주 매수 선행에 상승 개장 창업판 0 02%↑'},
#  {'subject': '임금이 더위 피했던  경회루 에서 특별한 여름 피서'},
#  {'subject': '하이컷  양양 서피비치와 함께한 하이컷 썸머 페스타 성료'},
#  {'subject': ' 용병 아닌 가족  카데나스 논란 때문인가 더 없이 아름다웠던 도슨의 이별식'},
#  {'subject': '이원석 검찰총장   검사 탄핵 청문회  불출석'},
#  {'subject': ' 육아삼쩜영   더우면 숲으로  이러다 휴가를 망쳤습니다'},
#  {'subject': '박명수 뉴진스 향한 삼촌팬 고백   선배님 하는데 예뻐  언제나 팬이고 응원  라디오쇼  종합 '},
#  {'subject': ' 사랑의 안단테  김보라  시크 귀여운 매력으로 눈도장'},
#  {'subject': '김영록 전남시사  국민의힘 인요한 최고위원 만남'},
#  {'subject': '국민의힘 인요한 최고위원 면담'},
#  {'subject': '농민 쌀값 인상 촉구'},
#  {'subject': '강원도  전국 최초로 수의직 공무원 6급 임용 추진'},
#  {'subject': ' 라면 왜 끓여  김동연 격노에 안희정 전 비서  강한 기시감 '},
#  {'subject': '용인 수지구  하천 수질오염물질 배출 시설 관리 강화'},
#  {'subject': ' 인터뷰  정인숙 대구 동구의회 의장  섬세하고 균형 잡힌 정책  주민들 다양한 요구 반영할 것 '},
#  {'subject': '금감원  직원 사문서 위조 은폐 한화투자증권에  기관경고  조치 '},
#  {'subject': '유엔 회원국  사이버범죄 방지 협약 승인'},
#  {'subject': '폭염 속 실종 치매노인 찾은 수색견  야크  부산경찰청장 공로패'},
#  {'subject': ' 디올백 사건  담당 권익위 국장 사망  힘들다  유서 남겨'},
#  {'subject': '관용 전기차 보유 지자체  충전기 지상이전 주차금지 검토도'},
#  {'subject': '트레저 준규  맑은 피부미남  ★포토 '},
#  {'subject': '주말에도  축축  올해 폭염  광복절 지나도 안 꺾일듯'},
#  {'subject': '동메달에도  굳은 표정  北 방철미  임애지  단 한 마디 에 미소 도대체 뭐라고 했길래 파리 2024 '},
#  {'subject': '치킨마루  2024 펩시 페스타 스크래치 쿠폰 이벤트 열어'},
#  {'subject': ' 다시 증가  관광 회복세 제주 외국인 방문객만 100만명'},
#  {'subject': '은가은♥박현호  열애 인정  트롯 커플  탄생'},
#  {'subject': '구로역서 선로 점검 중 사고 코레일 30대 직원 2명 사망'},
#  {'subject': '글로벌 금리 추종하며 2bp 내외 상승 외인  국채선물 순매수 채권분석 '},
#  {'subject': 'TV조선  키든타임  시즌2로 돌아왔다 정준하 정다은 새MC 합류'},
#  {'subject': '한지민 한예슬 공효진 레이디제인 사랑 공식   10세 연하남이 좋아 '},
#  {'subject': ' 1인 1음료 에 격분한 중화권 손님 카페 난장판 행패  업주 분노'},
#  {'subject': ' 장중수급포착  테크윙  외국인 기관 동시 순매수 주가  5 73%'},
#  {'subject': ' 장중수급포착  씨앤씨인터내셔널  외국인 기관 동시 순매수 주가  6 98%'},
#  {'subject': '사격 은메달 김예지  기자회견 중 실신 응급조치 후 의식 되찾아'},
#  {'subject': ' 12뉴스  오늘의 주요뉴스'},
#  {'subject': ' 이시각헤드라인  8월 9일 뉴스센터'},
#  {'subject': '사격 김예지 기자회견 중 실신 10여분만에 회복'},
#  {'subject': ' Here we go  드디어  홀란드 백업  탈출 맨시티 떠나 ATM과 5년 계약 체결→곧 마드리드 도착'},
#  {'subject': '임애지  비밀로 하겠습니다  북한 방철미도 뒤늦게 미소'},
#  {'subject': '하윤경  청순 하트  포토엔HD '},
#  {'subject': '트레저 윤재혁  하트 받으세요  ★포토 '},
#  {'subject': ' 사진 하윤경  스윗하트 '},
#  {'subject': '키움증권  연금저축 계좌서 ETF 비중 60% 넘어 '},
#  {'subject': ' 폐국 위기  TBS  김어준  사재 털어서라도 우리 도와야 '},
#  {'subject': '국내 증시 반등 위안화 강세 환율  장중 1360원대로 급락 외환분석 '},
#  {'subject': '김준호♥김지민 결혼계획  삐걱   등 떠밀리는 기분  오은영 조언은  Oh 쎈 이슈 '},
#  {'subject': '眞 정서주 VS 美 오유진  진성 노래로 맞대결  100점 속출   미스쓰리랑  종합 '},
#  {'subject': '28세 연하女 사진 찍어준 방시혁  우연히  해명에도 나온 LA 목격담'},
#  {'subject': '하윤경  환하게 인사  포토엔HD '},
#  {'subject': ' 장중수급포착  태광  외국인 기관 동시 순매수 주가  8 47%'},
#  {'subject': ' 장중수급포착  SK이노베이션  외국인 기관 동시 순매수 주가  4 40%'},
#  {'subject': '순창군 조선대  농촌사랑 동행순창  협약 체결'},
#  {'subject': '한복의 멋'},
#  {'subject': '교원그룹  어린이 과학 잡지  과학소년  400호 발간'},
#  {'subject': ' 리볼버 → 검은 수녀들   카카오엔터 풍성한 라인업'},
#  {'subject': '에오스 블랙  8월 한달 간  해피빈 더블기부  캠페인 실시'},
#  {'subject': ' 속보  사격 은메달 김예지  기자회견 중 쓰러졌다 10분만에 회복'},
#  {'subject': ' 사진 하윤경  당고머리에 꾸안꾸 패션 '},
#  {'subject': '성매매 후 돈 안내고 튀더니  신고하면 피차 피곤하잖아   뻔뻔 남성 영상 '},
#  {'subject': ' 불운의 부상  한국 떠나는 도슨  키움은 그냥 떠나보내지 않는다 부상 회복 기원 행사'},
#  {'subject': '강릉 청년마을  강릉살자  지역과 청년 담은 브랜드 팝업 열었다'},
#  {'subject': '한복의 아름다움'},
#  {'subject': 'PGA투어 8승  필드의 쇼맨  로드리게스  88세로 타계'},
#  {'subject': ' See you again  로니 도슨  불운한 부상에 쓰러진  해피 히어로   감동적인 응원 받고 내년 기약했다'},
#  {'subject': ' 감사합니다  오희준  불안함 느끼던 20대 내 모습 생각나  종영소감'},
#  {'subject': '트레저 도영  예쁜눈 인사  ★포토 '},
#  {'subject': '한복의 미'},
#  {'subject': '광주 남구  주민사업체 4곳  관광두레 상품  홍보  나서'},
#  {'subject': '오세훈 시장  강남3 용산구 전역 토지거래 허가구역 지정 검토 '},
#  {'subject': '서산 성연면 한식뷔페 이용객  고열 오한 복통 설사  증세 호소'},
#  {'subject': ' TOP10 확실  대한민국  12년 만에 일본도 제칠까'},
#  {'subject': '파키스탄 나딤  라이벌 인도 초프라 제치고 창던지기 金 획득 파리 2024 '},
#  {'subject': ' 장중수급포착  포스코인터내셔널  외국인 기관 동시 순매수 주가  4 31%'},
#  {'subject': ' 장중수급포착  하나마이크론  외국인 기관 동시 순매수 주가  4 65%'},
#  {'subject': '서린상사   KZ트레이딩 으로 새출발 고려아연 정체성 강화'},
#  {'subject': '與   野 영수회담 먼저  요구에  민생회복 진정성 의심 '},
#  {'subject': ' 장중수급포착  한국타이어앤테크놀로지  외국인 기관 동시 순매수 주가  2 82%'},
#  {'subject': '서울 그린벨트 해제   5년 내 주택 8만 가구 공급'},
#  {'subject': ' 영상   팀코리아 응원봉  살 수 있나요   IOC도 당황한 올림픽 신문물  K 응원봉 '},
#  {'subject': '경찰청  현대차 기아와  실시간 교통 신호 정보  활용해 실외이동로봇 시연'},
#  {'subject': '비투비 이민혁  허리 디스크 고백  통증 극심해 몸도 못 가눴다   by PDC '},
#  {'subject': ' 어떤 일이 있어도 돌아오고 싶어  수술 기로에 선 도슨  내년에도  마라탕후루  볼 수 있을까'},
#  {'subject': ' 에미상 후보  이태원 참사 다큐  9월 26일을 기다립니다   이태원 참사 생존자의 이야기 '},
#  {'subject': ' 영어울렁증  파트리샤  이태원 가면 외국인이 말 걸까봐  '},
#  {'subject': '부천사회적기업협의회  지역아동 880명에 물놀이 자유이용권 기부'},
#  {'subject': '단아한 우리 한복'},
#  {'subject': '사격 김예지  기자회견 중 쓰러졌다 회복  긴장 피로 누적된 듯 '},
#  {'subject': '코로나19 확산  무서운 속도  환자 4주간 6배 폭증'},
#  {'subject': '순창군  조선대학교와  농촌사랑 동행순창  협약'},
#  {'subject': ' 혼인신고 한 건이라도 더 받자  中지자체들  칠석날 연장근무'},
#  {'subject': '日방위성  방위 관련 기업 100개사  뇌물 비리  일제 점검'},
#  {'subject': '권선택 전 대전시장  사면 복권  초읽기 지역 정치권 촉각'},
#  {'subject': ' 장중수급포착  기아  외국인 기관 동시 순매수 주가  1 77%'},
#  {'subject': ' 장중수급포착  포스코퓨처엠  외국인 기관 동시 순매수 주가  4 26%'},
#  {'subject': ' AI D리포트  사격 김예지  회견 중 쓰러졌다 회복 피로 누적 긴장 추정'},
#  {'subject': ' 스포츠머그  2위와 격차가 이 정도나   사상 최고 허들러  매클로플린  6번째 세계 신기록 세우며 우승'},
#  {'subject': '한강공원에서 전기차 충전 가능해진다 티비유   찾아가는 전기차 충전 서비스  제공'},
#  {'subject': '이종석  팬들과 돌아보는 여정 데뷔 14주년 기념 전시회 개최'},
#  {'subject': ' 나는 솔로  레전드 경신  돌싱 특집으로 돌아온다'},
#  {'subject': '2024 한복상점 개막'},
#  {'subject': '함소원 진화 각각 생방송  딸 입 막고 얼굴 상처 여전 반쪽짜리 불화설 수습 이슈와치 '},
#  {'subject': '사격 김예지  회견 중 실신했다 회복 피로 누적 긴장 추정 종합 '},
#  {'subject': ' 공급책 총망라 정부 의지 돋보이지만 GB 해제 필요성 등 의문 '},
#  {'subject': '보이넥스트도어 첫 연기 도전  하석진과  마이 아티 필름  호흡  공식 '},
#  {'subject': ' 파리올림픽 2024   세계 랭킹 24위  김유진의 반란 1 2 4 5위 도장 깨고 金'},
#  {'subject': '넥슨   FC 프로 챔피언스 컵  8월 19일 개최'},
#  {'subject': ' 장중수급포착  GS건설  외국인 기관 동시 순매수 주가  4 45%'},
#  {'subject': ' GTX C  개통 물건너갔다   정책 바로보기 '},
#  {'subject': '인권위  과도한 두발 제한 중단해야  학교 측  불수용 '},
#  {'subject': ' 현장   온스딸 그 옷  모녀가 함께 입는다  CJ온스타일 VVIP 프라이빗 행사 가보니'},
#  {'subject': ' 세계가 주목한  사격 은메달리스트 김예지  기자회견 중 쓰러졌다 회복 파리2024 '},
#  {'subject': ' 10m 공기권총 은메달리스트  김예지  기자회견 중 실신 10분 만에 현장에서 회복  파리올림픽 '},
#  {'subject': '한국  파리올림픽에서 역대 최고 성과 거둔다  이종세의 스포츠 코너 '},
#  {'subject': '주거 상권 중심지 발돋움 청량리  강북의 강남  노린다'},
#  {'subject': ' 비웃어   손가락욕  사소한 다툼도  무조건 학폭 소송 '},
#  {'subject': ' 리볼버   화면 뚫고 나오는 전도연X지창욱X임지연의 에너지'},
#  {'subject': ' 재산 축소 신고  혐의 양문석 검찰 송치'},
#  {'subject': '광복절 사면 복권에 김경수 조윤선 포함'},
#  {'subject': '청라 아파트 지하주차장 스프링클러  관리소 직원이 껐다'},
#  {'subject': 'SKT  환자정보 유출  전자처방 서비스 9년만에 무죄'},
#  {'subject': '여야 앞다퉈  반도체법  당론 추진 모처럼 정책 경쟁'},
#  {'subject': ' 포토친구  운현궁의 여름 풍경'},
#  {'subject': '외국인 투자금 9개월째 순유입 규모는 두 달 연속 감소'},
#  {'subject': '주요 증인 다 빠지고 이런 청문회 왜 하나'},
#  {'subject': '외국인  9개월연속  바이코리아     7월 증시서 22 4억달러 순유입'},
#  {'subject': '거야  청문회 중독  석달새 16회 19 21대 총 13회 넘어서'},
#  {'subject': '하윤경  상큼한 출근길  포토엔HD '},
#  {'subject': '한국도자재단   2024경기도자비엔날레  최종 수상작 57점 발표'},
#  {'subject': '北접경지 주민  강 썰물 때 걸어서 귀순  북 경비 허술 '},
#  {'subject': '대북정찰  백두 금강  기술 유출  북한에 해킹당한 방산업체 더 있다 '},
#  {'subject': '70년 된  적국 기밀  조항 첨단정보전쟁 미아 전락'},
#  {'subject': '고소영  ♥장동건 닮은 아들  딸 뒷모습 공개'},
#  {'subject': 'K리그2 안산  제7대 사령탑에  시리우스  이관우 감독 선임'},
#  {'subject': 'SSG  17 18일 한화전서 디즈니코리아와 함께  더 존 브랜드 데이  진행'},
#  {'subject': '공수처 수사 이후 특검  한동훈   채상병  입장 바꾸나'},
#  {'subject': '박찬대  민주당 최고위서 발언'},
#  {'subject': '국회 과방위 방송장악 관련 청문회 이진숙 불참'},
#  {'subject': ' 장중수급포착  한미사이언스  외국인 기관 동시 순매수 주가  3 54%'},
#  {'subject': ' 리포트 브리핑 KT&G   실적호조  주주환원 정책↔연간 눈높이 조정  목표가 110 000원   하이투자증권'},
#  {'subject': '경찰  실시간 교통 신호 이동로봇 연동 시연회 개최'},
#  {'subject': '시장  돌변   긴급 금리인하 필요없다 '},
#  {'subject': '현대차 기아 자율주행 배송로봇 신호등 보고 횡단보도 건넜다'},
#  {'subject': 'NCT 재현  첫 솔로 앨범  J  스케줄 포스터 공개 기대감 UP'},
#  {'subject': '박찬대  독립기념관장 임명 취소해야  14일 규탄대회 종합2보 '},
#  {'subject': '답변하는 조성은 방통위 사무처장'},
#  {'subject': '인도네시아 진출 우리기업 지원을 위한 현지 규제 대응 설명회 열려'},
#  {'subject': '땅속에 배수관 바로 묻으니   물 빠짐 쏙   논콩 수확량 쑥 '},
#  {'subject': '근로자 73%  조직문화 맞지 않아 회사 관둔다 '},
#  {'subject': '폭염 속 식중독 주의보  예방수칙은   정책 바로보기 '},
#  {'subject': '사격 은메달 김예지  기자회견 중 쓰러졌다 회복 장시간 긴장 탓인 듯'},
#  {'subject': ' 사상 최소 인원 으로 예상 뒤집은 올림픽 金 최다 타이 신기록 가능할지 종목 살펴보니'},
#  {'subject': ' 개인보다 집단  수재민 돕기 위한 총력전 분위기 조성 데일리 북한 '},
#  {'subject': ' 단독   그놈  때문에 잔잔한 바다에서 어부가 죽었다'},
#  {'subject': '민주당   통신사찰 피해 신고 센터  오늘부터 운영'},
#  {'subject': '외인  9개월째  바이 코리아  주식 채권에 22억 달러 순유입'},
#  {'subject': '외국인  국내 증시에 9개월째 돈 넣었지만 순유입 규모 축소'},
#  {'subject': '세메스 한국생산기술연구원  반도체 제조혁신 상생협력 MOU'},
#  {'subject': ' 김건희 명품백 조사  권익위 국장 사망 유승민  종결 과정 밝혀야 '},
#  {'subject': '인권위  두발 제한 개선해야  학교  기존 교칙 따르기로 '},
#  {'subject': '뷰피 플랫폼  화해  운영사 버드뷰 김경일 신임 대표 선임'},
#  {'subject': '인권위  학생 두발제한은 개성 발현권 자기결정권 침해 '},
#  {'subject': 'SM엔터  직원 1인당 50주 스톡그랜트 지급  창사 이래 최초 '},
#  {'subject': ' 알림  연합뉴스 콘텐츠 저작권 고지'},
#  {'subject': '이종석  어느덧 데뷔 14주년 어린 시절→미공개 사진 대방출 전시 개최'},
#  {'subject': '실외 이동로봇   실시간 신호정보  받아 운행 안전 높인다'},
#  {'subject': '김제시   제26회 김제지평선축제 서 부스 운영 참여업체 모집'},
#  {'subject': '한국공대  2주기 대학혁신지원사업 성과평가  최고 S등급'},
#  {'subject': '외국인  7월 한국 주식 채권 3조원어치 사들여'},
#  {'subject': '외국인 9개월째  바이 코리아  7월 증시서 22 4억불  사자 '},
#  {'subject': '박명수  뉴진스 팬심 폭발  그냥 내 아이들 같아 팬이고 사랑한다   라쇼   종합 '},
#  {'subject': '방송장악 관련 청문회 열린 국회 과방위'},
#  {'subject': '경찰 교통 신호 정보  민간 로봇  눈  됐다'},
#  {'subject': '황정은의 소설  백의 그림자 를 필사하며 깨달은 것  송지현의 자 독 추 '},
#  {'subject': '엔미디어플랫폼   GETO PC방 핫타임 이벤트  실시'},
#  {'subject': '경찰청  실외 이동로봇 시연회 횡단보도 건넌다'},
#  {'subject': ' 컨콜 종합  컴투스  2분기 연속 흑자 하반기도 실적 개선  심혈 '},
#  {'subject': '굳건한 반도체 기대 외인 9개월째 국내 주식 순매수'},
#  {'subject': ' 사진 주종혁  여심 사로잡는 손하트 '},
#  {'subject': '與  김여사 조준한 野특검법에 강경론 제삼자추천안  브레이크 '},
#  {'subject': '이경규  꼬꼬면  인기 회상  한국 움직인 경제인 2위 '},
#  {'subject': '외국인 9개월째 국내주식  사자  총 33조원 순유입'},
#  {'subject': ' POP이슈  음주운전  BTS 슈가  최고 30km  전동 스쿠터  확인 팬덤 분열 3일째'},
#  {'subject': '흔들리는 KIA   대투수  양현종 내세워 선두 수성 나선다  프로야구 9일 경기 일정 '},
#  {'subject': '반도체 업황 기대감에 외국인  韓주식 9개월 연속 순매수'},
#  {'subject': '방송장악 관련 청문회 진행중인 국회 과방위'},
#  {'subject': ' 장중수급포착  LG에너지솔루션  외국인 기관 동시 순매수 주가  1 09%'},
#  {'subject': ' 장중수급포착  저스템  외국인 5일 연속 순매수행진 주가  3 33%'},
#  {'subject': '오늘의 날씨  24  08  09  10시 '},
#  {'subject': '한혜진  500평 별장 화재 위기 긴급 다이어트 중  큰일났다   한혜진  종합 '},
#  {'subject': '구급차 이동하는 김예지 선수'},
#  {'subject': '더 강력해진 채 상병 특검법 내놓은 민주당 한동훈 압박 본격화'},
#  {'subject': '8월의 우주쇼  페르세우스 유성우  집에서 본다 안될과학 과천과학관 유튜브 생중계'},
#  {'subject': '병원 이송 위해 구급차 탑승하는 김예지 선수'},
#  {'subject': '병원 이송되는 김예지 선수'},
#  {'subject': '주종혁  훈훈하게 양손 브이  포토엔HD '},
#  {'subject': '병원 이송 위해 실려 나오는 김예지 선수'},
#  {'subject': '오세훈  신고가 지역 예의주시 토허제 확대 검토 '},
#  {'subject': ' 건물서 대형견이 쿵  인도서 산책 중 여아 깔려 사망'},
#  {'subject': '기자회견 도중 쓰러진 김예지 선수'},
#  {'subject': ' 레드벨벳 아이린이 반미 反美 에 꽂혔다고   해외팬들 오역에 웃음폭발'},
#  {'subject': ' 민희진 대표가 온갖 욕과 폭언으로 짓밟고 모욕   성희롱 피해자 입 열었다 MD이슈  종합 '},
#  {'subject': ' 장중수급포착  핑거스토리  외국인 5일 연속 순매수행진 주가  2 55%'},
#  {'subject': ' 장중수급포착  라이콤  외국인 8일 연속 순매수행진 주가  4 50%'},
#  {'subject': '대전 타일 판매시설 화재 직원 4명 긴급 대피 인명피해 없어'},
#  {'subject': ' 홍대부터 부산까지  KT&G 상상마당  문화예술 프로그램 진행'},
#  {'subject': '광주 광산구  여름철 호흡기 감염병 예방 총력'},
#  {'subject': '천안시  축구종합센터  진입도로 일부 개통'},
#  {'subject': '신하균  왜 맨날 정장입나 했더니 디테일 소름  감사합니다 '},
#  {'subject': '들것에 실려 나오는 김예지 선수'},
#  {'subject': ' 최강야구  뉴페이스 영입  장시원 PD  깜짝 선물 준비   Oh 쎈 예고 '},
#  {'subject': '中 7월 소비자물가 0 5%↑ 디플레 우려 한숨 돌렸나 종합 '},
#  {'subject': '극도의 긴장 김예지 기자회견 중  일시적 쇼크  10분만에 회복'},
#  {'subject': '하태하  안타까운 가정사 고백  父 부도 후 빚더미 쓰리잡 뛰어   특종  종합 '},
#  {'subject': '하이닉스 S&P 신용등급 1단계 상향  BBB '},
#  {'subject': '네이버  2분기 영업익 4727억  검색 커머스 핀테크 모두 성장 '},
#  {'subject': '금메달 1개만 더   황금주말  한국 올림픽 새 역사 쓴다 2024 파리올림픽 '},
#  {'subject': ' 승리 요정이 되고 싶어  가수 이승윤  두산 유니폼 입고 힘찬 시구'},
#  {'subject': '세계 24위  비장의 왼발차기  세계 1 2 4 5위 다 날렸다 2024 파리올림픽 '},
#  {'subject': '네이버 2분기 역대 최대 실적    라인야후 지분 축소 검토 안해 '},
#  {'subject': '향군 기재부에 호국선양활동 예산 25억원 지원 요청 내년부터 보훈기금 지원 전격 중단'},
#  {'subject': '양천구  CCTV로 쓰레기 무단투기 뿌리 뽑는다'},
#  {'subject': '김건희 조사 공직자 사망에 여권서도  이 나라 정상인가 '},
#  {'subject': ' 포토  박충권 국민의힘 의원  방송장악  관련 청문회 질의'},
#  {'subject': '민주  권익위 간부 사망  상임위 차원에서 철저히 진상규명 '},
#  {'subject': '정부가 재건축조합 민원해결사인가 '},
#  {'subject': ' 속보  사격 은메달 김예지  기자회견 중 갑자기 쓰러져 지금은 회복'},
#  {'subject': ' 장중수급포착  진영  외국인 5일 연속 순매수행진 주가  4 65%'},
#  {'subject': ' 종합  컴투스홀딩스    제노니아  글로벌 확장 하반기 엑스플라 블록체인 집중 '},
#  {'subject': ' 컨콜  네이버 2분기 호실적 최수연 대표  초개인화 기술로 수익 창출 집중 '},
#  {'subject': ' 마라도 자장면 배달시킬 분  드론 배송 상용화  배달료는 '},
#  {'subject': ' 사진 주종혁  편안한 복장으로 브이 '},
#  {'subject': '1호선 구로역서 작업차량 충돌로 2명 사망 1명 중상'},
#  {'subject': '김포시 양곡도서관  북치는 토요일 저녁  플리마켓 참여자 모집'},
#  {'subject': ' 컨콜  컴투스  손실 부담  자회사  축소 예정 경영 효율화 집중 '},
#  {'subject': 'XG  빌보드  글로벌 재팬 송즈 익스클루딩 재팬  1위'},
#  {'subject': ' 전기 쇠꼬챙이로 도살    경기특사경  화성 불법 도살 현장 적발'},
#  {'subject': '장수군의회 최한주 의장   2024 우수의정활동의원 선정대상  수상'},
#  {'subject': ' 사진 하윤경  사랑스러운 출근길 '},
#  {'subject': '우미희망재단  국가유공자 후손 85명에게 장학금 전달'},
#  {'subject': '이천시  출산축하금 산후조리비 사용처 확대'},
#  {'subject': '대검  현직 검사  탄핵 청문회 증인으로 못 불러 '},
#  {'subject': '사격 은메달 김예지 선수  기자회견 도중 실신'},
#  {'subject': ' 장중수급포착  오픈엣지테크놀로지  외국인 5일 연속 순매수행진 주가  2 39%'},
#  {'subject': ' 스브스픽   밀양 성폭행  가해자 신상 폭로한 유튜버  결국 구속'},
#  {'subject': '유상임 과기장관 후보자 장남  미국서 마리화나 사용'},
#  {'subject': ' 포토  답변하는 조성은 방송통신위원회 사무처장'},
#  {'subject': ' 반포 신고가 예의주시  오세훈  토허제 확대 검토  일문일답 '},
#  {'subject': '119 신고전화 녹취록으로 본 긴박했던  전기차 화재  상황'},
#  {'subject': '검찰총장∙탄핵 검사  野 주도  탄핵 검사 청문회  불출석'},
#  {'subject': '목포시  삽진항  국가어항 지정 예비 항 1위 선정'},
#  {'subject': ' 안세영  비즈니스석 요구 눈높이가 손흥민 김연아급  협회 발언 파장'},
#  {'subject': ' 종합  네이버  2분기 매출 영업익 모두 사상 최대 하반기  AI 로 성장 모멘텀 기대'},
#  {'subject': ' 반포 신고가 예의주시  오세훈  토허제 확대 검토  일문일답 '},
#  {'subject': '119 신고전화 녹취록으로 본 긴박했던  전기차 화재  상황'},
#  {'subject': '검찰총장∙탄핵 검사  野 주도  탄핵 검사 청문회  불출석'},
#  {'subject': '목포시  삽진항  국가어항 지정 예비 항 1위 선정'},
#  {'subject': ' 안세영  비즈니스석 요구 눈높이가 손흥민 김연아급  협회 발언 파장'},
#  {'subject': ' 종합  네이버  2분기 매출 영업익 모두 사상 최대 하반기  AI 로 성장 모멘텀 기대'},
#  {'subject': '中 도핑 무마 의혹 파헤치다 역풍 맞은 美'},
#  {'subject': 'NCT 재현  12일  Roses   Dandelion  선공개'},
#  {'subject': '블랙핑크 지수  데뷔 8주년 소감  축하하고 앞으로도 잘 부탁해  전문 '},
#  {'subject': '진에어  9월 14일 부산 나고야 신규 취항  주7회 매일 운항 '},
#  {'subject': ' 필리핀 이모님  751가구 신청  요리는 안되고  영어책 읽기는 되나요  '},
#  {'subject': 'DL이앤씨  안전관리자 직무교육 실시 전원 CPR 수료증 취득'},
#  {'subject': '광주은행  풍수해 피해업체  긴급경영안정자금 1000억 원 특별 지원'},
#  {'subject': ' ♥안정환  이혜원 딸 리원  뉴욕대에 미모까지 겸비 母 닮아 미인'},
#  {'subject': ' 장중수급포착  제이엔비  외국인 5일 연속 순매수행진 주가  5 12%'},
#  {'subject': ' 장중수급포착  제일엠앤에스  외국인 5일 연속 순매수행진 주가  3 14%'},
#  {'subject': ' 포토  과방위 청문회 출석 답하는 조성은 사무처장'},
#  {'subject': '안철수  권익위 간부 사망에  여야 싸우며 중간에 낀 공무원들 벼랑 끝 내몰아 '},
#  {'subject': ' 포토   방송장악  관련 청문회 답하는 조성은 사무처장'},
#  {'subject': ' 트로피 없어도 클럽 레전드  토트넘  바이에른 뮌헨 홈경기서 케인과 다이어어 특별 선물'},
#  {'subject': ' 리볼버  캐릭터 분석→비하인드 스토리까지 지창욱X이정재 메가토크 성료'},
#  {'subject': '전주시  전주여행의  시민전문가  양성과정 교육생 모집'},
#  {'subject': '응급 출산 이유 있었네  김승현♥  장정윤  아기 작고 양수 적어 '},
#  {'subject': '기업은행  인공지능 기반 소상공인 경영지원 서비스 개발'},
#  {'subject': '한국비엔씨  지속형 비만치료제 후보물질서 높은 내성 평가 확인  글로벌 진출 본격화 '},
#  {'subject': '삼성라이온즈 야구장 간 대구경북병무청 병역진로설계'},
#  {'subject': ' 속보   사격 은메달  김예지  기자회견 도중 쓰러져 실신'},
#  {'subject': '중국 0%대 저물가 지속  소비 키울 추가 부양책 주목 종합 '},
#  {'subject': '말복 앞두고 서울 삼계탕 한 그릇  평균 1만7000원 처음 넘었다'},
#  {'subject': '축구 국가대표 홍현석  UECL 3차 예선 71분 소화 헨트는 2 2 무'},
#  {'subject': '사격 銀 김예지  기자회견 중 경련과 함께 실신 현재는 회복 중'},
#  {'subject': '정애리  60대인데 30대처럼 유연  중년에게  이 동작  권해'},
#  {'subject': ' 머리가 이게 뭐야  설명해 봐  더 브라위너   꽁지 머리 로 훈련장 등장→과르디올라도 웃으면서 조롱'},
#  {'subject': 'BNK자산운용  주식형 펀드 중장기 수익률 국내 1위'},
#  {'subject': ' 장중수급포착  퀄리타스반도체  외국인 5일 연속 순매수행진 주가  5 49%'},
#  {'subject': ' 리포트 브리핑 한온시스템   2Q24 Review  어두운 터널을 지나는 중  목표가 6 000원   하이투자증권'},
#  {'subject': '김경수 복권 심사에 野  술렁  특검 공방 재점화'},
#  {'subject': ' 엠카  전소미  Ice Cream  녹였다'},
#  {'subject': '올림픽 최다 금메달 쾌거  21세기형 도전 정신 보여줬다 사설 '},
#  {'subject': '더 황당한 野의 3번째 채상병특검법과 공수처 무능 사설 '},
#  {'subject': ' 보존가치 낮은 곳만 해제 신혼부부 주택 공급될 것 '},
#  {'subject': '12년만에 풀리는  서울 그린벨트  수도권 주택공급 확대  총력전 '},
#  {'subject': ' 40도 폭염경보 에도 웃을 수 있는 이유 신세계를 맛본 마황과 동희진  유진형의 현장 1mm '},
#  {'subject': '근대5종 전웅태 높이뛰기 우상혁  동반 金  노리는 선수촌 절친 2024 파리올림픽 '},
#  {'subject': ' 활 총 검 발  활약   MZ 거침없는 도전 깜짝 성과 2024 파리올림픽 '},
#  {'subject': '軍  북  미사일발사대 250대  전방 배치 동향 아직 없어  대북 확성기 방송 계속'},
#  {'subject': 'NCT DREAM  영어 싱글  Rains in Heaven  23일 발매'},
#  {'subject': '트럼프  내가 지면 경제공황 온다   대통령 연준 발언권  피력'},
#  {'subject': ' 포토  답변하는 조능희 전 MBC플러스 사장'},
#  {'subject': ' 종합  컴투스  체질 개선 속 2Q 약진  자체 개발 퍼블리싱으로 흑자 기조 유지 '},
#  {'subject': ' 시흥 슈퍼마켓 살인  피의자 구속기소 16년 만에 재판대에'},
#  {'subject': '2차전지 인사이트 外 신간 '},
#  {'subject': '엑소 찬열  첫 솔로 앨범  Black Out  8일 발매'},
#  {'subject': ' 감독 픽  공격 보강 원한다 한 시즌 만에 프리미어리그 복귀 '},
#  {'subject': '호라이즌  여름 시장 도저장 13일 서머송 발표'},
#  {'subject': '무엇이든 이뤄 내는 강한 마음  신간 '},
#  {'subject': '쿠팡   8월 파워풀위크  행사 진행 최대 75% 할인'},
#  {'subject': '화순군  의료급여수급권자 건강검진 수검 독려 이벤트'},
#  {'subject': '방시혁  여성 비제이와 LA서 포착  관광지 식당 안내 '},
#  {'subject': '속삭임 우묵한 정원  신간 '},
#  {'subject': '최다니엘  MBN 한일 로맨스  혼전연애  MC 발탁'},
#  {'subject': ' 컴백  엔믹스  오감 만족 시키는 스웨그  비주얼 필름 공개  '},
#  {'subject': '함평군  제25회 함평모악산꽃무릇축제 안전관리계획 심의'},
#  {'subject': '엔비디아 웨이  신간 '},
#  {'subject': '컴투스홀딩스  하반기 웹3 수익 사업 본격 추진   엑스플라에 20개 게임 온보딩 '},
#  {'subject': '김경수 복권 소식에 친명계 일각  야권 분열 노림수  견제'},
#  {'subject': ' 사진 하윤경  사랑의 볼하트 '},
#  {'subject': ' 장중수급포착  모니터랩  외국인 5일 연속 순매수행진 주가  3 76%'},
#  {'subject': '더존비즈온 KG ICT  기업용솔루션  OmniEsol  확산 업무협약 체결'},
#  {'subject': '한국비엔씨  위고비 계열 지속형 비만치료제 1차 후보물질  높은 In vitro 활성 및 In vivo 효과 확인 '},
#  {'subject': ' 장중수급포착  코칩  외국인 5일 연속 순매수행진 주가  4 49%'},
#  {'subject': '우신시스템  계약종료일 기준 변경으로 잦은 정정공시 방지  신규 수주 이상 無 '},
#  {'subject': ' 장중수급포착  엔젤로보틱스  외국인 5일 연속 순매수행진 주가  1 89%'},
#  {'subject': ' 포토  이상휘 의원 질의에 답하는 조능희 전 MBC플러스 사장'},
#  {'subject': '박명수  박보검  고맙다고 연락와 정말 잘 자랐다  극찬  라디오쇼  종합 '},
#  {'subject': ' 포토  질의 답변하는 조능희 전 MBC플러스 사장'},
#  {'subject': '박명수 머스크도 반한 사격 김예지 선수 감탄  배경화면 해야 할 듯  너무 멋있어  라디오쇼 '},
#  {'subject': 'SSG닷컴  이탈리아 식전주 문화 상징하는  폭스 감자칩  판매 시작'},
#  {'subject': '與  김경수 복권 관측에  여야 협치 계기 될 수도 '},
#  {'subject': '김여정  조카 주애에 깍듯이 허리 숙여 北 후계 구도 굳히나'},
#  {'subject': '실종자 찾아 생명 구한 또 하나의  경찰 에게'},
#  {'subject': '사격 은메달 김예지  기자회견 중 쓰러져    현장서 10분만에 회복 '},
#  {'subject': '이상일 용인시장  파리올림픽 다이빙 경기장 찾아 김수지 선수 응원'},
#  {'subject': '일생에 한번은 헌법을 읽어라  신간 '},
#  {'subject': '숟가락이 주렁주렁 톱 여배우의 친환경 패션'},
#  {'subject': '미즈노 브랜드 스포츠 헤리티지 아이템 H LINE 에이치라인  컬렉션 출시'},
#  {'subject': '검찰총장  검사탄핵 청문회 불출석  정치적 중립 훼손 '},
#  {'subject': '野  김경수 복권 관측에 환영  尹 의도는 의심 '},
#  {'subject': '檢   티메프  본부장급 임원 참고인 조사 수사 속도'},
#  {'subject': '인천 터널서 트레일러 3중 추돌 화물차 운전자 숨져'},
#  {'subject': ' 단독  무면허로 40km 질주한 미성년자 시민 추격 끝에 검거'},
#  {'subject': '서린상사   KZ 트레이딩 으로 사명 변경'},
#  {'subject': ' 장중수급포착  버넥트  외국인 5일 연속 순매수행진 주가  2 36%'},
#  {'subject': '중국 역대급 폭염에  기현상   임신한 차가 나타났다 '},
#  {'subject': '김연수 한컴대표 27일 주총서 지주사 사내이사 선임'},
#  {'subject': ' 포토  윤도한 전 수석 관련 PPT 화면 보는 최민희 위원장'},
#  {'subject': '강화도에서 8년만에 촛불집회 열려  윤석열 탄핵이 평화다 '},
#  {'subject': '더 시에나 라이프  신세계 부산 센텀시티 매장 오픈 박인비 사인회 연다'},
#  {'subject': ' 헬기 인명사고 방지  산림청 밤나무 방제  헬기에서 드론으로 변경'},
#  {'subject': ' 오이 잘 씻어도 농약 남는다고   껍질 꼭 벗기고 먹으라는데  진짜 '},
#  {'subject': '실종 치매노인부터 도주범까지 경찰견  야크  놀라운 공'},
#  {'subject': ' 가해자만 감싸고 돈 민희진 거짓말 못 참겠다  성희롱 피해자 입 열었다'},
#  {'subject': '은가은♥박현호  트로트 연상연하 커플 탄생  올 초 연인으로 발전 '},
#  {'subject': ' 더워도 촉촉해야 예뻐  에이블리  글로시 메이크업  상품 검색 급증'},
#  {'subject': '병원 이송되는 사격 김예지'},
#  {'subject': '엑소 찬열  데뷔 12년 만에 첫 솔로  블랙아웃  28일 발매'},
#  {'subject': '홍현희 제이쓴  내 아들 커가며 남의 아이도 돕는다'},
#  {'subject': '도공 광주전남본부  광주 고려인마을 후원 및 고령 보행자 교통안전교육'},
#  {'subject': '맘스터치   사랑의 하츄핑  협업 세트 3종 출시'},
#  {'subject': '장수군   귀농귀촌 한마음대회  개최  군민 모두 행복한 장수 에 일조'},
#  {'subject': '2분기 호실적에 웃은  네카오  AI 등 성장동력 확보는 과제'},
#  {'subject': '오세훈  훼손된 그린벨트 풀 것 신고가 지역 예의주시 '},
#  {'subject': ' 장중수급포착  우리이앤엘  외국인 5일 연속 순매수행진 주가  3 23%'},
#  {'subject': ' 장중수급포착  에이텀  외국인 5일 연속 순매수행진 주가  2 35%'},
#  {'subject': '드루킹사건 김경수 복권論  선거 범죄 무관용 무너지나 사설 '},
#  {'subject': ' 부고 곽노정씨 별세外'},
#  {'subject': ' 인사 보건복지부外'},
#  {'subject': '동북아역사재단 사무총장에 정용상'},
#  {'subject': '게임물관리위 신임위원에 서태건 정의준'},
#  {'subject': ' 수국에 미친 공무원 덕분에 장생포가 살아났어요 '},
#  {'subject': ' 죽은 반려견에 영광을  8년만에 금 다시 딴 네덜란드 선수 2024 파리올림픽 '},
#  {'subject': '개성파 배우 김정태가  시집  냈다'},
#  {'subject': '코트라  아프리카 어린이 디지털교육위해 컴퓨터 기부'},
#  {'subject': '아모레퍼시픽재단  문화와 예술  연구 지원공모'},
#  {'subject': ' 협력사와 동반성장  한화  푸드트럭 건강검진 지원'},
#  {'subject': '에쓰오일  버려진 비닐장갑 모아 주유장갑 제작 배포'},
#  {'subject': '모로코  이집트에 6 0 완승 남자 축구 동메달 2024 파리올림픽 '},
#  {'subject': '美 유니폼에  누구든 모두가  무슨 의미  2024 파리올림픽 '},
#  {'subject': '파키스탄 나딤  창던지기 92m97 올림픽新으로 정상 2024 파리올림픽 '},
#  {'subject': '후프와 한 몸처럼 2024 파리올림픽 '},
#  {'subject': '여기저기 눈에 띄네 또 하나의 국가대표  한글  2024 파리올림픽 '},
#  {'subject': 'IOC 북한 선수들 삼성폰 안 받았다  2024 파리올림픽 '},
#  {'subject': '구글 메타  10대 청소년 타깃광고 비밀계약 논란'},
#  {'subject': '네타냐후  하마스 기습공격 방어실패  첫 사과'},
#  {'subject': '영국  AI 편법 인수 안 봐줘  아마존도 조사'},
#  {'subject': '방글라데시 과도정부 출범 총선관리 질서유지 과제'},
#  {'subject': '베네수엘라 부정선거에 니카라과는 성직자 탄압 중남미 좌파연대 파열음'},
#  {'subject': ' 과학자 애국심  강조한 中베이다이허 회의'},
#  {'subject': '檢출신 해리스 트럼프의 끼어들기 인신공격 어떻게 맞설까'},
#  {'subject': '女탁구 단체  16년만의 올림픽 메달 향해  스매싱  2024 파리올림픽 '},
#  {'subject': '루시 엔플라잉 볼빨간사춘기  2024 GMF  24팁 1차 라인업 공개'},
#  {'subject': '일본   난카이 대지진  불안 속 대비 태세   일부 지역 혼란도'},
#  {'subject': '살 빼다 큰일난다  발암 발작 탈모  42개 직구 식품  위해성분  검출'},
#  {'subject': '골프 양희영  막판 역전극 쓸까 2024 파리올림픽 '},
#  {'subject': '의료 大개혁 시작할 때다 뉴스와 시각 '},
#  {'subject': ' 장중수급포착  제일일렉트릭  외국인 5일 연속 순매수행진 주가  4 01%'},
#  {'subject': ' 밥캣 로보틱스 합병  두산  40일 내 금융당국 주주 설득할까'},
#  {'subject': '소수파 한동훈의 거야 대적법 오승훈의 시론 '},
#  {'subject': ' 소맥세트  2만원 시대에 1캔 1000원 마트표 맥주 불티'},
#  {'subject': '전도연의 불편함과 대중의 불편함 이정우 기자의 소실점 '},
#  {'subject': '플로리다 별장서 기자회견하는 트럼프 전 대통령'},
#  {'subject': '국립횡성숲체원  둔내고랭지 토마토축제  홍보체험관  운영'},
#  {'subject': '서원나눔   장애인 이동권 개선 지원  5000만원 기부'},
#  {'subject': ' 컨콜종합  컴투스  내 외부 신작 가리지 않고 라인업 두텁게 확보 '},
#  {'subject': '한국콜마  2분기 영업익 717억   전년比 29% ↑'},
#  {'subject': ' 속보 파리올림픽  사격銀  김예지  기자회견 중 쓰러졌다'},
#  {'subject': '트럼프  대통령 재임 때 파월 의장과 강하게 충돌 '},
#  {'subject': '카카오 케이 토스뱅크  서울 저신용 소상공인 대상 1000억 보증대출 실시'},
#  {'subject': '경남도  3개 시군과 대규모 관광개발 민간 투자유치 본격화'},
#  {'subject': '한국AI스마트홈산업협회 스마트 인테리어 포럼   제7기 스마트인테리어 사업자 세미나  오는 8월 20 21일 개최'},
#  {'subject': '동부건설  3천155억원 규모  강릉∼제진 철도 공사  수주'},
#  {'subject': ' 나라 곳간  비상에  올해 지자체 교부세  3조2천억 줄어들 듯 '},
#  {'subject': ' 장중수급포착  플레이디  외국인 11일 연속 순매수행진 주가  2 41%'},
#  {'subject': '최재성  금투세 완화론 꺼낸 이재명  전술적 미스 '},
#  {'subject': ' 장중수급포착  하이텍팜  외국인 5일 연속 순매수행진 주가  5 12%'},
#  {'subject': ' 장중수급포착  하이드로리튬  외국인 5일 연속 순매수행진 주가  3 52%'},
#  {'subject': '사격 은메달 김예지  기자회견 중 쓰러졌다 회복'},
#  {'subject': ' 한달 뒤면 가을이네  FW시즌 준비 나선 패션업계'},
#  {'subject': ' 포토  조성은 사무처장  방송장악  관련 청문회 답변'},
#  {'subject': ' 왓IS  직접 사진 촬영도 방시혁 의장 BJ 과즙세연 목격담 이어져'},
#  {'subject': ' 엄마친구아들  정해인 정소민   재난  같은 재회'},
#  {'subject': '트럼프  대통령은 연준에 최소한 발언권 가져야 '},
#  {'subject': '남북 여자 복서 시상대 나란히 北 방철미  임애지 한마디에 미소'},
#  {'subject': '트럼프  연준 이사회나 의장 보다 내 직감이 낫다 '},
#  {'subject': ' 포토  의원들 질의에 답하는 조성은 방통위원회 사무처장'},
#  {'subject': ' 사격 은메달  김예지  기자회견 중 실신 의식 회복 후 병원 이송'},
#  {'subject': '전현무  파리올림픽 역도 중계 11일  사당귀  본방 이어 본다'},
#  {'subject': ' 공식   선업튀  김영수役 허형규  키이스트와 재계약 체결 신스틸러 존재감ing'},
#  {'subject': '전현무  11일 올림픽 역도경기 생중계  비인기 종목 관심 위해   사당귀  '},
#  {'subject': ' 건강하게 다시 만나요  진정한 영웅 로니 도슨 아쉬운 작별인사  O  SPORTS '},
#  {'subject': ' 놀면서 기부하자  롯데월드  걸음 기부 캠페인 진행'},
#  {'subject': '한화시스템 수주공시   TOD Ⅲ형 수리부속 PBL 사업 외 6항목 839 7억원  매출액대비  3 42 % '},
#  {'subject': '中 소비자 물가 5개월래 최고 6개월 연속 상승세'},
#  {'subject': '안산  새 사령탑에 이관우 감독 선임  젊고 강한 팀으로 변화할 것 '},
#  {'subject': '충북청주   베테랑 미드필더  김선민과 3년 재계약 체결'},
#  {'subject': ' 성관계 한번에 2만원  남편에 돈 요구한  황당  아내  이혼 당했다'},
#  {'subject': '서울시  보존 가치 낮은 그린벨트 해제  미래세대 주택공급 확대 '},
#  {'subject': '美정보당국  민주당 전대  트럼프 피격 보복  우려 2024美대선 '},
#  {'subject': '코오롱ENP  2분기 영업익 97억 전년비 8 9%↑'},
#  {'subject': ' 장중수급포착  SK리츠  외국인 5일 연속 순매수행진 주가  1 94%'},
#  {'subject': '中  美반도핑기구 조사 요구  제보 대가로 도핑 은폐 '},
#  {'subject': ' 장중수급포착  사조오양  외국인 11일 연속 순매수행진 주가  9 95%'},
#  {'subject': '안철수 의원  고등학교 신분증 공개  지금 모습 보이네 '},
#  {'subject': ' 나 방시혁 아냐  과즙세연  노출 여행→방송 회장 해명까지  활활   엑 스레이 '},
#  {'subject': '이경규  꼬꼬면  1억개  초대박  그 해 한국 움직인 경제인 2위 1위는 스티브 잡스 '},
#  {'subject': ' 포토  이진숙 방통위원장 불출석한  방송장악  관련 청문회'},
#  {'subject': '해리스 트럼프 9월10일 첫 TV토론 확정'},
#  {'subject': '뉴저지 한인 여성  경찰 총격에 사망  물통 들고 있었을뿐 '},
#  {'subject': ' 8월  1000만원대 구매 가능  GS글로벌  BYD 1t트럭 T4K 프로모션'},
#  {'subject': '슈가  음주운전 후폭풍 거세다 양세찬 저격→BTS 강제 자숙까지  종합 '},
#  {'subject': '중국 건국75주년  수교32주년  한중서화 예술전  화장 華章   8일 개막'},
#  {'subject': '구로역서 작업차 접촉사고  코레일 직원 2명 사망'},
#  {'subject': ' 포토  질의하는 박충권 국민의힘 의원'},
#  {'subject': ' 해파리 공포 에 피서 인파 끊긴 동해안 제철 오징어도 사라질 판'},
#  {'subject': '中 7월 소비자물가 0 5%  쑥      디플레 우려 잦아드나'},
#  {'subject': '친윤  정점식 교체 참았다  홍영림은   한동훈  여연원장 인선 장고'},
#  {'subject': '할리우드 여배우 시사회 의상에 숟가락  주렁주렁   이유는 '},
#  {'subject': ' 오락가락  일본은행 금리정책  연내 추가 인상 가능성 줄어 '},
#  {'subject': '병원 이송되는 사격 김예지'},
#  {'subject': ' 과징금 피해야  애플  EU 빅테크 규제에 앱스토어 약관 추가변경'},
#  {'subject': '119 신고전화 녹취록으로 본 긴박했던  전기차 화재  상황'},
#  {'subject': '김포시의회  2024년 청렴 교육 실시'},
#  {'subject': '美서 판매된 삼성전자 전기레인지 112만대 결함보상'},
#  {'subject': '오세훈  보존가치 낮은 그린벨트 해제 신혼부부에게 주택공급할 것 '},
#  {'subject': '이원석 총장  검사탄핵 청문회 불출석 사유서 제출'},
#  {'subject': ' T포토  보이넥스트도어 태산  청초한 분위기 '},
#  {'subject': ' 장중수급포착  LG전자우  외국인 5일 연속 순매수행진 주가  1 79%'},
#  {'subject': '지수연  1인 2역 도전 뮤지컬  부치하난  캐스팅'},
#  {'subject': ' 장중수급포착  캠시스  외국인 5일 연속 순매수행진 주가  2 39%'},
#  {'subject': ' 장중수급포착  나이벡  외국인 5일 연속 순매수행진 주가  9 54%'}]

# %%
# 해당 데이터에서, 기사 내용인 , message 부분의 값 추출 작업. 
# 임시 저장 문자열
message = ""
# data = [{딕션너리1},{딕션너리2},{딕션너리3},...]
for item in data:
  if "subject" in item.keys():
    # (\w : 문자, 숫자 의미 ) 앞에 ^(not) 가 아닌 것은 모두 -> 공백으로 변경함. 
    # 하나의 임시 메세지 문자열 변수에 담기
    message = message + re.sub(r"[^\w]"," ", item["subject"]) + ""
message
# Out:
# ' 떡 드세요  박세리  쏟아진 명언집   3 5  으뜸 파리올림픽 숨진 권익위 간부 사망 사건  부검 없이 종결키로기자회견 중 쓰러진 김예지  회복 후 병원 이송하윤경  권모술수 주종혁  실제 성격은 큐트보이  12시엔 엔하이픈  ROMANCE   UNTOLD   日 레코드협회 첫  플래티넘  인증 획득광주 전남 7월 주식 시장 활발 삼성전자 가장 많이 거래김재중  16년만 드디어 SBS  인기가요  출격 SM 퇴사 후 처음가평군   칼봉산휴양림 목공체험장 운영  민간 위탁 체결SM  전직원에 20억 스톡그랜트 지급 1인당 50주넘어지려는 노인 잡아줬는데  폭행  신고 CCTV로 억울함 밝혀내與  김경수 복권 여야 협치 구심점 될 것  야 4885  영화  추격자  실존인물  마약 판매로 검거 무슨 일24살 BJ와 포착된 방시혁  관광지 안내해준 것뿐 롯데물산  두 번째 지속가능경영보고서 발간  2040 탄소중립 로드맵 실천 강화 구급차로 옮겨지는 김예지 선수환하게 웃으며 답변하는 김예지오직 마카오에서만  일상탈출 액티비티 8이스라엘 공격 고심하는 이란  가자 휴전시 보복안 폐기 검토 파리올림픽 10m 공기권총 은메달리스트 김예지 선수 환영식박형수  완벽한 캐릭터 소화력으로 선보일  폭군  속  조 과장 질의에 답변하는 김예지 선수최정 삼진 추신수 병살타 데뷔 첫 10SV 작성 ERA 10 80 9 56 시절에서 이렇게 달라지다니  히어로즈 최후의 1차지명 약속 지켰다그날의 충돌 이후 효자 외인 떠나고  최고참도 시즌 아웃  내년에도 키움에서 볼 수 있나 2억원대  중고거래 사기 일당 항소심서 감형 경쟁률 70대 1  낙산사  나는 절로  주형환 저출산위 부위원장   나는 둘로  돼 돌아가길 카카오게임즈   프렌즈팝  9주년 업데이트 사전등록 실시 유상임 아들 美 불법체류 당시 마리화나 의혹  野  과기장관 후보 사퇴 요구구급차 불렀는데 출동 경찰 총격에 20대 한인여성 사망 종합 임영웅  팬클럽  영웅바라기 서포터즈  파주시장애인복지관에 데뷔 8주년 기념 후원 절 소개팅  찾은 주형환  솔로가 절 와서 둘이 돼 돌아가길 다이어트 근육강화제 등 해외직구식품 42 에  위해성분  검출 여자 400m 허들 최강자  매크로플린  세계기록 또 깼다 왕관 헤드폰  착용 아이유  9월 콘서트 메인포스터 공개하윤경  산뜻한 비주얼  포토엔HD  리포트 브리핑 한온시스템   만조 滿潮 를 기다리며  목표가 6 500원   현대차증권 리포트 브리핑 한국타이어앤테크놀로지   누가 피크아웃 소리를 내었는가   목표가 68 000원   현대차증권전북자치도 추석 특별 정책자금 850억원 규모 12일부터 지원서울 중구  어린이 건강한 식생활 뮤지컬로 배워요저고위 부위원장  청춘남녀 만남과 인연 지속하도록 돕겠다 국가유산청   망건장  전영인씨 국가무형유산 보유자로 인정 사격銀  김예지  회견 중 실신후 회복 하루도 못 쉬었다 종합 치료제 못 찾아 발만 동동  비수도권 더 심각 입으로 즐기는  맛카오  미식 로드 5 마카오 A to Z  여행 미리보기 마카오 A to Z  조금 특별한 마카오 여행법양산시  환경업무 근로자 대상  특별 안전교육  실시상황 설명하는 심민 임실군수커리 제임스  224   농구 에펠탑  넘을까 올림픽  리포트 브리핑 KT G   2Q24 Review  담배 성장 견조  서프라이즈   목표가 120 000원   현대차증권 리포트 브리핑 고려아연   양호한 실적 지속  주주환원도 인상적  목표가 720 000원   현대차증권 리포트 브리핑 웹젠   P E 10배를 뚫으려면 신규 IP 필수  목표가 22 000원   현대차증권 리포트 브리핑 카카오   톡비즈 3rd 수익원   AI 서비스가 온다  목표가 65 000원   현대차증권고흥군  망고 재배 교육으로 신소득 작물 육성고흥군  숯불구이 맛  여름 미식 여행  제안 생생경제  살 빼려고 제로 음료 골랐는데 다이어트에 도움 안 된다  왜 셀트리온   짐펜트라  미국 26개 처방집 등재실신한 사격 김예지 선수  의식 명료  대화도 가능 한미  민관 에너지 협력 채널 구축 합의 무탄소에너지 활용 등 논의KT   2분기 실적 매출 4조5483억원 영업익 3588억원코로나 입원환자 4주간 6배 급증 65세 이상이 65 김예지 선수 기자회견 중 쓰러졌다 회복  병원 이송병원으로 이송되는 김예지 선수 르포  이렇게 힘들었나 티메프 경안자금  개시 30분만에 100건 쇄도   14kg  한혜연  사진 찍을 맛나는 슬렌더 몸매   SHOT  동메달 건 남북 복서 임애지 방철미  나란히 시상대에  파리올림픽 연예인야구대회  치열 8강전 예고 입장 무료주종혁   주터뷰 잘하고 오겠습니다   포토엔HD 내년  라이즈 체계  전국 시행 앞두고 현장 소통 가솔린 3736만원  기아  K8 계약 시작이랜드 리테일  GOOD BUY  SUMMER FESTA 스페셜 행사 HD현대 막내 조선소   국내 첫  액화CO₂운반선  건조 착수대웅제약   역대 최대  2분기 영업익 496억원 전년比 37 1   리포트 브리핑 클리오   2Q24 Review  견조한 해외 성장 지속  목표가 47 000원   현대차증권 리포트 브리핑 한국전력   2Q24 컨센서스 소폭 상회  여전히 목마른 전기요금 인상  목표가 30 000원   대신증권10년전 뉴욕 한복판의 곰 사체 미스터리 대선 후보 케네디 짓이었다 심야괴담회  시즌4 김주령 괴스트 출연사격 김예지  기자회견 도중 실신 회복 후 병원 이송 파리올림픽 아이들극장에서 온 가족 함께 즐기는  종로 가족공연축제  헤럴드포토  플랫폼H 경남가리비수협 업무협약 체결클래식 선율 속 자유로움이 돋보이는 특별한 무대  8월 서울 예술의전당 콘서트 개최 마이데이터 전 분야 확산  규제개혁위 9일 심의 사진 하윤경  햇살 미소 날리며 인사 방송인 홍현희 제이쓴 부부  아들 생일 맞아 1000만원 기부 리포트 브리핑 LG   하반기 자사주 소각 발표 기대  목표가 95 000원   대신증권 리포트 브리핑 삼화전기   2Q24 Review  흔들림 없이  목표가 100 000원   현대차증권 올림픽 별거 아니야  벌써 金 2개  태권도 분위기 좋다 오늘은 80kg 서건우 차례   올림픽 NOW K리그2 안산  제7대 사령탑에  시리우스  이관우 감독 선임 정영선  이 땅에 숨 쉬는 모든 것을 위하여   레드닷 디자인 어워드 최고상주종혁   제가 수줍음이 많아서요   포토엔HD 세계랭킹 1위 女근대5종 성승민  펜싱 랭킹 라운드 8위 김선우는 11위 컨콜 네이버 대표  AI검색 서비스  큐  연내 모바일 출시 검토 SM엔터  직원 1인당 50주  스톡그랜트  지급 20억 규모 분명 범행을 자백했는데  30대 여성 성폭행 혐의로 체포된  日 엔도 후계자   갑자기 불기소처분고령 금융소비자 불편에 응답한 삼성화재  콜센터 대리안내 제도 시행 마켓인  버튜버  콘텐츠 경제 요소 결합한 복합 엔터 산업으로 성장  리포트 브리핑 LG   고요함 속의 outperform  목표가 100 000원   현대차증권 리포트 브리핑 시프트업   상저하고의 니케   중국 스팀 기대감 유효  Not Rated   현대차증권김재중  16년 만에 지상파 음방 뚫었다 11일  인기가요  출격183cm에 57kg  감량에 하루 발차기 1만번  세계랭커 압도  김유진의 초인적인 인내 리포트 브리핑 롯데케미칼   2Q24 review   경쟁사 대비 부진한 이익 회복세  목표가 125 000원   삼성증권신안군  멸종위기 참달팽이 18마리 하태도에 방사 디케이앤디  52주 신고가 경신  최근 3일간 외국인 대량 순매수 중국서 유학왔어요  미중 갈등 속  캘리포니아주 판다  환대 윤일상 프로듀싱 그룹 쓰리피스  RE100  홍보대사 발탁함평군  소금 식초 된장 만들기  쌀 소비촉진 앞장 성남시 판교수질복원센터 악취 개선 공사에 12억원 투입관세청   티메프  추가 피해 방지 위해 수사 착수경과원  창업혁신공간  투자 혹한기  단비 입주기업 매출 85  증가 사격 스타  김예지  인터뷰 중 실신 후 회복 병원 후송  지병 없다  피로 긴장으로 추정   파리2024 조희연  실질적 변화 위해 교권보호 3법 추가 제 개정 필 ...

# %%
# 품사 태깅, Okt 패키지 사용하기. 
nlp = Okt()
message_N = nlp.nouns(message)
message_N
# Out:
# ['떡',
#  '박세리',
#  '명언',
#  '집',
#  '으뜸',
#  '파리올림픽',
#  '권익위',
#  '간부',
#  '사망',
#  '사건',
#  '부검',
#  '종결',
#  '기자회견',
#  '중',
#  '김예지',
#  '회복',
#  '후',
#  '병원',
#  '송하윤',
#  '경',
#  '권모술수',
#  '주종',
#  '혁',
#  '실제',
#  '성격',
#  '큐트',
#  '보이',
#  '하이픈',
#  '레코드',
#  '협회',
#  '첫',
#  '플래티넘',
#  '인증',
#  '획득',
#  '광주',
#  '전남',
#  '주식',
#  '시장',
#  '활발',
#  '삼성',
#  '전자',
#  '가장',
#  '거래',
#  '김재중',
#  '인기가요',
#  '출격',
#  '퇴사',
#  '후',
#  '처음',
#  '가평군',
#  '칼봉산',
#  '휴양림',
#  '목공',
#  '체험',
#  '운영',
#  '민간',
#  '위탁',
#  '체결',
#  '직원',
#  '스톡',
#  '그랜트',
#  '지급',
#  '주',
#  '노인',
#  '폭행',
#  '신고',
#  '로',
#  '김경수',
#  '복권',
#  '여야',
#  '협치',
#  '구심',
#  '점',
#  '것',
#  '영화',
#  '추격자',
#  '실존',
#  '인물',
#  '마약',
#  '판매',
#  '검거',
#  '무슨',
#  '일',
#  '살',
#  '포착',
#  '방시혁',
#  '관광지',
#  '안내',
#  '것',
#  '롯데',
#  '물산',
#  '두',
#  '가능',
#  '보고서',
#  '발간',
#  '탄소',
#  '중립',
#  '로드맵',
#  '실천',
#  '강화',
#  '구급차',
#  '김예지',
#  '선수',
#  '답변',
#  '김예지',
#  '오직',
#  '마카오',
#  '일상',
#  '탈출',
#  '액',
#  '티비',
#  '티',
#  '이스라엘',
#  '공격',
#  '고심',
#  '이란',
#  '휴전',
#  '시',
#  '보복',
#  '안',
#  '폐기',
#  '검토',
#  '파리올림픽',
#  '공기권총',
#  '은메달',
#  '리스트',
#  '김예지',
#  '선수',
#  '환영',
#  '박형수',
#  '캐릭터',
#  '소화',
#  '폭',
#  '속',
#  '조',
#  '과장',
#  '질의',
#  '답변',
#  '김예지',
#  '선수',
#  '최정',
#  '삼진',
#  '추신수',
#  '병살타',
#  '데뷔',
#  '첫',
#  '작성',
#  '시절',
#  '히어로즈',
#  '최후',
#  '차지',
#  '약속',
#  '그날',
#  '충돌',
#  '이후',
#  '효자',
#  '외인',
#  '최고',
#  '시즌',
#  '아웃',
#  '내년',
#  '볼',
#  '수',
#  '중고',
#  '거래',
#  '사기',
#  '일당',
#  '항소심',
#  '감형',
#  '경쟁률',
#  '낙산사',
#  '나',
#  '절로',
#  '주형',
#  '환',
#  '저출산',
#  '위',
#  '부위',
#  '원장',
#  '나',
#  '둘',
#  '카카오',
#  '게임',
#  '프렌즈',
#  '팝',
#  '주년',
#  '업데이트',
#  '사전',
#  '등록',
#  '실시',
#  '유',
#  '상임',
#  '아들',
#  '불법체류',
#  '당시',
#  '마리화나',
#  '의혹',
#  '과',
#  '장관',
#  '후보',
#  '사퇴',
#  '요구',
#  '구급차',
#  '출동',
#  '경찰',
#  '총격',
#  '한인',
#  '여성',
#  '사망',
#  '종합',
#  '임영웅',
#  '팬클럽',
#  '영웅',
#  '서포터즈',
#  '파주시장',
#  '애인',
#  '복지관',
#  '데뷔',
#  '주년',
#  '기념',
#  '후원',
#  '절',
#  '소개팅',
#  '주형',
#  '환',
#  '솔로',
#  '절',
#  '둘',
#  '다이어트',
#  '육강',
#  '화제',
#  '등',
#  '해외',
#  '직구',
#  '식품',
#  '위해',
#  '성분',
#  '검',
#  '여자',
#  '허들',
#  '최강',
#  '매크로',
#  '린',
#  '세계',
#  '기록',
#  '또',
#  '왕관',
#  '헤드폰',
#  '착용',
#  '아이유',
#  '콘서트',
#  '메인',
#  '포스터',
#  '공개',
#  '윤경',
#  '비주',
#  '얼',
#  '포토',
#  '리포트',
#  '브리핑',
#  '시스템',
#  '만조',
#  '를',
#  '목표',
#  '현대차',
#  '증권',
#  '리포트',
#  '브리핑',
#  '한국',
#  '타이어',
#  '앤',
#  '테크놀로지',
#  '누가',
#  '피크',
#  '아웃',
#  '소리',
#  '목표',
#  '현대차',
#  '증권',
#  '전북',
#  '자치도',
#  '추석',
#  '특별',
#  '정책',
#  '자금',
#  '규모',
#  '지원',
#  '서울',
#  '중구',
#  '어린이',
#  '식생활',
#  '뮤지컬',
#  '고위',
#  '부위',
#  '원장',
#  '청춘',
#  '남녀',
#  '만남',
#  '인연',
#  '지속',
#  '국가',
#  '유산',
#  '청',
#  '망건',
#  '인씨',
#  '국가',
#  '무형',
#  '유산',
#  '보유',
#  '인정',
#  '사격',
#  '김예지',
#  '회견',
#  '중',
#  '실신',
#  '후',
#  '회복',
#  '하루',
#  '못',
#  '종합',
#  '치료',
#  '제',
#  '못',
#  '발',
#  '동동',
#  '비',
#  '수도권',
#  '더',
#  '심각',
#  '입',
#  '맛',
#  '미식',
#  '로드',
#  '마카오',
#  '여행',
#  '미리보기',
#  '마카오',
#  '조금',
#  '마카오',
#  '여행',
#  '법',
#  '양산시',
#  '환경',
#  '업무',
#  '근로자',
#  '대상',
#  '특별',
#  '안전교육',
#  '실시',
#  '상황',
#  '설명',
#  '심민',
#  '임실군',
#  '커리',
#  '제임스',
#  '농구',
#  '에펠탑',
#  '올림픽',
#  '리포트',
#  '브리핑',
#  '담배',
#  '성장',
#  '견조',
#  '서프라이즈',
#  '목표',
#  '현대차',
#  '증권',
#  '리포트',
#  '브리핑',
#  '고려아연',
#  '양호',
#  '실적',
#  '지속',
#  '환원',
#  '인상',
#  '목표',
#  '현대차',
#  '증권',
#  '리포트',
#  '브리핑',
#  '웹젠',
#  '배',
#  '신규',
#  '필수',
#  '목표',
#  '현대차',
#  '증권',
#  '리포트',
#  '브리핑',
#  '카카오',
#  '톡',
#  '비즈',
#  '수익',
#  '서비스',
#  '목표',
#  '현대차',
#  '증권',
#  '고흥군',
#  '망고',
#  '재배',
#  '교육',
#  '소득',
#  '작물',
#  '육성',
#  '고흥군',
#  '숯불',
#  '구이',
#  '맛',
#  '여름',
#  '미식',
#  '여행',
#  '제안',
#  '생생',
#  '경제',
#  '살',
#  '제로',
#  '음료',
#  '다이어트',
#  '도움',
#  '안',
#  '왜',
#  '셀트리온',
#  '짐펜트',
#  '미국',
#  '개',
#  '처방',
#  '집',
#  '등',
#  '신한',
#  '사격',
#  '김예지',
#  '선수',
#  '의식',
#  '명료',
#  '대화',
#  '가능',
#  '한미',
#  '민관',
#  '에너지',
#  '협력',
#  '채널',
#  '구축',
#  '합의',
#  '무',
#  '탄소',
#  '에너지',
#  '활용',
#  '등',
#  '논의',
#  '실적',
#  '매출',
#  '영업',
#  '익',
#  '입원',
#  '환자',
#  '주간',
#  '배',
#  '급증',
#  '세',
#  '이상',
#  '김예지',
#  '선수',
#  '기자회견',
#  '중',
#  '회복',
#  '병원',
#  '이송',
#  '병원',
#  '이송',
#  '김예지',
#  '선수',
#  '르포',
#  '티메프',
#  '경안',
#  '자금',
#  '개시',
#  '건',
#  '쇄도',
#  '한혜연',
#  '사진',
#  '찍',
#  '맛나',
#  '슬렌더',
#  '몸매',
#  '동메달',
#  '건',
#  '남북',
#  '복서',
#  '임애',
#  '방철',
#  '상대',
#  '파리올림픽',
#  '연예인',
#  '야구',
#  '대회',
#  '치열',
#  '강전',
#  '예고',
#  '입장',
#  '무료',
#  '주종',
#  '혁',
#  '터뷰',
#  '포토',
#  '내년',
#  '라이즈',
#  '체계',
#  '전국',
#  '시행',
#  '현장',
#  '소통',
#  '가솔린',
#  '기아',
#  '계약',
#  '시작',
#  '이랜드',
#  '리테일',
#  '스페셜',
#  '행사',
#  '현대',
#  '막내',
#  '조선소',
#  '국내',
#  '첫',
#  '액화',
#  '운반',
#  '선',
#  '건조',
#  '착수',
#  '대웅제약',
#  '역대',
#  '최대',
#  '영업',
#  '익',
#  '년',
#  '리포트',
#  '브리핑',
#  '클리오',
#  '견조',
#  '해외',
#  '성장',
#  '지속',
#  '목표',
#  '현대차',
#  '증권',
#  '리포트',
#  '브리핑',
#  '한국전력',
#  '컨센서스',
#  '폭',
#  '상회',
#  '목',
#  '전기요금',
#  '인상',
#  '목표',
#  '대신',
#  '증권',
#  '뉴욕',
#  '복판',
#  '곰',
#  '사체',
#  '미스터리',
#  '대선',
#  '후보',
#  '케네디',
#  '심야',
#  '괴담',
#  '회',
#  '시즌',
#  '김주',
#  '령',
#  '괴스트',
#  '출연',
#  '사격',
#  '김예지',
#  '기자회견',
#  '도중',
#  '실신',
#  '회복',
#  '후',
#  '병원',
#  '이송',
#  '파리올림픽',
#  '아이',
#  '극장',
#  '온',
#  '가족',
#  '종로',
#  '가족',
#  '공연',
#  '축제',
#  '헤럴드',
#  '포토',
#  '플랫폼',
#  '경남',
#  '가리비',
#  '수협',
#  '업무',
#  '협약',
#  '체결',
#  '클래식',
#  '선율',
#  '속',
#  '자유',
#  '로움',
#  '무대',
#  '서울',
#  '예술의전당',
#  '콘서트',
#  '개최',
#  '마이',
#  '데이터',
#  '전',
#  '분야',
#  '확산',
#  '규제',
#  '개혁',
#  '위',
#  '심의',
#  '사진',
#  '하윤',
#  '경',
#  '햇살',
#  '미소',
#  '인사',
#  '방송인',
#  '홍현희',
#  '제이',
#  '부부',
#  '아들',
#  '생일',
#  '기부',
#  '리포트',
#  '브리핑',
#  '하반기',
#  '자',
#  '사주',
#  '소각',
#  '발표',
#  '기대',
#  '목표',
#  '대신',
#  '증권',
#  '리포트',
#  '브리핑',
#  '삼화',
#  '전기',
#  '목표',
#  '현대차',
#  '증권',
#  '올림픽',
#  '별거',
#  '벌써',
#  '개',
#  '태권도',
#  '분위기',
#  '오늘',
#  '서건우',
#  '차례',
#  '올림픽',
#  '리그',
#  '안산',
#  '제',
#  '사령탑',
#  '시리우스',
#  '이관우',
#  '감독',
#  '선임',
#  '정영선',
#  '이',
#  '땅',
#  '숨',
#  '모든',
#  '것',
#  '위',
#  '레드',
#  '닷',
#  '디자인',
#  '어워드',
#  '최고',
#  '주종',
#  '혁',
#  '제',
#  '수줍음',
#  '포토',
#  '세계',
#  '랭킹',
#  '위',
#  '근대',
#  '종',
#  '승민',
#  '펜싱',
#  '랭킹',
#  '라운드',
#  '위',
#  '김선우',
#  '위',
#  '컨콜',
#  '네이버',
#  '대표',
#  '검색',
#  '서비스',
#  '큐',
#  '연내',
#  '모바일',
#  '출시',
#  '검토',
#  '엔터',
#  '직원',
#  '주',
#  '스톡',
#  '그랜트',
#  '지급',
#  '규모',
#  '분명',
#  '범행',
#  '자백',
#  '여성',
#  '성폭행',
#  '혐의',
#  '체포',
#  '엔도',
#  '후계',
#  '갑자기',
#  '불기소처분',
#  '고령',
#  '금융',
#  '소비자',
#  '불편',
#  '응답',
#  '삼성',
#  '화재',
#  '콜센터',
#  '대리',
#  '안내',
#  '제도',
#  '시행',
#  '마켓',
#  '버튜버',
#  '콘텐츠',
#  '경제',
#  '요소',
#  '결합',
#  '복합',
#  '엔터',
#  '산업',
#  '성장',
#  '리포트',
#  '브리핑',
#  '고요함',
#  '속',
#  '목표',
#  '현대차',
#  '증권',
#  '리포트',
#  '브리핑',
#  '시프트',
#  '업',
#  '상저',
#  '니케',
#  '중국',
#  '스팀',
#  '대감',
#  '유효',
#  '현대차',
#  '증권',
#  '김재중',
#  '지상파',
#  '음방',
#  '인기가요',
#  '출격',
#  '감량',
#  '하루',
#  '발차기',
#  '세계',
#  '랭커',
#  '압도',
#  '김유진',
#  '초인',
#  '인내',
#  '리포트',
#  '브리핑',
#  '롯데',
#  '케미칼',
#  '경쟁',
#  '사',
#  '대비',
#  '이익',
#  '회복',
#  '세',
#  '목표',
#  '삼성',
#  '증권',
#  '신안군',
#  '멸종위기',
#  '달팽이',
#  '마리',
#  '하태도',
#  '방사',
#  '디케이',
#  '앤디',
#  '주',
#  '신고',
#  '경신',
#  '최근',
#  '외국인',
#  '대량',
#  '매수',
#  '중국',
#  '유학',
#  '중',
#  '갈등',
#  '속',
#  '캘리포니아주',
#  '판다',
#  '환대',
#  '윤일상',
#  '프로',
#  '듀싱',
#  '그룹',
#  '피스',
#  '홍보',
#  '대사',
#  '발탁',
#  '함평군',
#  '소금',
#  '식초',
#  '된장',
#  '만들기',
#  '쌀',
#  '소비',
#  '촉진',
#  '앞장',
#  '성남시',
#  '판교',
#  '수질',
#  '복원',
#  '센터',
#  '악취',
#  '개선',
#  '공사',
#  '투입',
#  '관세청',
#  '티메프',
#  '추가',
#  '피해',
#  '방지',
#  '위해',
#  '수사',
#  '착수',
#  '경과',
#  '창업',
#  '혁신',
#  '공간',
#  '투자',
#  '혹',
#  '한기',
#  '단비',
#  '기업',
#  '매출',
#  '증가',
#  '사격',
#  '스타',
#  '김예지',
#  '인터뷰',
#  '중',
#  '실신',
#  '후',
#  '회복',
#  '병원',
#  '후송',
#  '지병',
#  '피로',
#  '긴장',
#  '추정',
#  '파리',
#  '조희연',
#  '실질',
#  '변화',
#  '위해',
#  '교권',
#  '보호',
#  '법',
#  '추가',
#  '제',
#  '개정',
#  '필요',
#  '김경수',
#  '복권',
#  '소식',
#  '환영',
#  '일각',
#  '정치',
#  '의도',
#  '우려',
#  '흥민',
#  '이형',
#  '이형',
#  '추천',
#  '규',
#  '헹크',
#  '이적',
#  '드주종혁',
#  '하트',
#  '포토',
#  '여자',
#  '복싱',
#  '은감',
#  '바',
#  '난민',
#  '팀',
#  '첫',
#  '메달',
#  '선사',
#  '급',
#  '동메달',
#  '파리',
#  '펄',
#  '어비스',
#  '국가',
#  '유산',
#  '청과',
#  '손',
#  '경복궁',
#  '아침',
#  '나라',
#  '서울',
#  '팀',
#  '리그',
#  '최',
#  '하위',
#  '안산',
#  '이관우',
#  '감독',
#  '선임',
#  '사진',
#  '주종',
#  '혁',
#  '포토',
#  '타임',
#  '리포트',
#  '브리핑',
#  '바이오',
#  '가야',
#  '방향',
#  '가장',
#  '먼저',
#  '목표',
#  '미래에셋',
#  '증권',
#  '강진',
#  '후',
#  '폭풍',
#  '일본',
#  '최악',
#  '대지진',
#  '오',
#  '이번',
#  '주말',
#  '폭염',
#  '치맥',
#  '올림픽',
#  '마지막',
#  '살',
#  '연하',
#  '은',
#  '가은',
#  '평소',
#  '이상형',
#  '박현호',
#  '만날',
#  '병원',
#  '열사병',
#  '기초',
#  '생활',
#  '수급',
#  '끝내',
#  '사망',
#  '곽준',
#  '빈',
#  '이동휘',
#  '한국',
#  '난생처음',
#  '곳',
#  '두려움',
#  '곽',
#  '기사',
#  '안성시',
#  '산후조리',
#  '비',
#  '지역화폐',
#  '경기',
#  '시',
#  '군',
#  '수',
#  '리포트',
#  '브리핑',
#  '넷마블',
#  '찐써프',
#  '이',
#  ...]

# %%
# 집계 데이터 기본 탐색, 모델 구축 하기. 
count = Counter(message_N)
count
# Out:
# Counter({'외국인': 73,
#          '포착': 65,
#          '수급': 65,
#          '주가': 63,
#          '장': 63,
#          '김예지': 57,
#          '증권': 50,
#          '리포트': 47,
#          '브리핑': 47,
#          '목표': 45,
#          '매수': 44,
#          '중': 43,
#          '기관': 40,
#          '포토': 39,
#          '동시': 39,
#          '회복': 34,
#          '사격': 33,
#          '연속': 32,
#          '위': 30,
#          '기자회견': 29,
#          '파리올림픽': 28,
#          '종합': 25,
#          '선수': 24,
#          '한국': 24,
#          '행진': 24,
#          '제': 23,
#          '청문회': 22,
#          '삼성': 20,
#          '은메달': 19,
#          '현대차': 19,
#          '올림픽': 19,
#          '사진': 19,
#          '최고': 18,
#          '실신': 18,
#          '한복': 18,
#          '사망': 16,
#          '혁': 16,
#          '후': 15,
#          '첫': 15,
#          '더': 15,
#          '병원': 14,
#          '주종': 14,
#          '복권': 14,
#          '것': 14,
#          '요구': 14,
#          '전': 14,
#          '경': 13,
#          '김경수': 13,
#          '공개': 13,
#          '영업': 13,
#          '개최': 13,
#          '명': 13,
#          '코로나': 13,
#          '주': 12,
#          '신고': 12,
#          '위해': 12,
#          '서울': 12,
#          '교육': 12,
#          '지역': 12,
#          '개월': 12,
#          '검사': 12,
#          '탄핵': 12,
#          '트럼프': 12,
#          '운영': 11,
#          '체결': 11,
#          '안': 11,
#          '정책': 11,
#          '지원': 11,
#          '실적': 11,
#          '인상': 11,
#          '익': 11,
#          '세': 11,
#          '이송': 11,
#          '공급': 11,
#          '로봇': 11,
#          '내': 11,
#          '국민': 11,
#          '방송': 11,
#          '등': 10,
#          '지속': 10,
#          '대상': 10,
#          '성장': 10,
#          '하윤': 10,
#          '네이버': 10,
#          '화재': 10,
#          '파리': 10,
#          '교육청': 10,
#          '불': 10,
#          '출석': 10,
#          '처': 10,
#          '관련': 10,
#          '힘': 10,
#          '광주': 9,
#          '로': 9,
#          '답변': 9,
#          '속': 9,
#          '실시': 9,
#          '경찰': 9,
#          '세계': 9,
#          '개': 9,
#          '매출': 9,
#          '환자': 9,
#          '티메프': 9,
#          '현장': 9,
#          '국내': 9,
#          '회': 9,
#          '인사': 9,
#          '기부': 9,
#          '증가': 9,
#          '그린벨트': 9,
#          '주택': 9,
#          '오세훈': 9,
#          '모두': 9,
#          '확대': 9,
#          '박세완': 9,
#          '상점': 9,
#          '장악': 9,
#          '사랑': 9,
#          '피': 9,
#          '키트': 9,
#          '주식': 8,
#          '직원': 8,
#          '검토': 8,
#          '주년': 8,
#          '아들': 8,
#          '과': 8,
#          '후보': 8,
#          '여성': 8,
#          '기아': 8,
#          '최대': 8,
#          '경남': 8,
#          '확산': 8,
#          '하반기': 8,
#          '오늘': 8,
#          '센터': 8,
#          '개선': 8,
#          '인터뷰': 8,
#          '하트': 8,
#          '미래에셋': 8,
#          '폭염': 8,
#          '증시': 8,
#          '사업': 8,
#          '조사': 8,
#          '딸': 8,
#          '사상': 8,
#          '전기차': 8,
#          '대통령': 8,
#          '쌀값': 8,
#          '권익위': 7,
#          '방시혁': 7,
#          '강화': 7,
#          '환영': 7,
#          '질의': 7,
#          '비주': 7,
#          '얼': 7,
#          '특별': 7,
#          '규모': 7,
#          '입': 7,
#          '수익': 7,
#          '의식': 7,
#          '역대': 7,
#          '협약': 7,
#          '기대': 7,
#          '감독': 7,
#          '선임': 7,
#          '이': 7,
#          '대표': 7,
#          '김유진': 7,
#          '피해': 7,
#          '수사': 7,
#          '피로': 7,
#          '긴장': 7,
#          '일본': 7,
#          '박현호': 7,
#          '경기': 7,
#          '서울시': 7,
#          '해제': 7,
#          '코리아': 7,
#          '이벤트': 7,
#          '정보': 7,
#          '인': 7,
#          '공무원': 7,
#          '공식': 7,
#          '팬': 7,
#          '준': 7,
#          '검찰총장': 7,
#          '글로벌': 7,
#          '진행': 7,
#          '재': 7,
#          '사무': 7,
#          '시장': 6,
#          '전자': 6,
#          '출격': 6,
#          '점': 6,
#          '판매': 6,
#          '살': 6,
#          '데뷔': 6,
#          '시즌': 6,
#          '수': 6,
#          '카카오': 6,
#          '유': 6,
#          '앤': 6,
#          '치료': 6,
#          '여행': 6,
#          '법': 6,
#          '배': 6,
#          '신규': 6,
#          '여름': 6,
#          '급증': 6,
#          '입장': 6,
#          '시작': 6,
#          '행사': 6,
#          '년': 6,
#          '컨콜': 6,
#          '중국': 6,
#          '대감': 6,
#          '이익': 6,
#          '추가': 6,
#          '투자': 6,
#          '팀': 6,
#          '급': 6,
#          '가은': 6,
#          '부산': 6,
#          '안전': 6,
#          '유입': 6,
#          '쇼': 6,
#          '이유': 6,
#          '때': 6,
#          '과제': 6,
#          '논란': 6,
#          '발매': 6,
#          '누적': 6,
#          '메': 6,
#          '최초': 6,
#          '탄생': 6,
#          '핫': 6,
#          '눈높이': 6,
#          '모집': 6,
#          '빅토리': 6,
#          '대구': 6,
#          '듯': 6,
#          '논': 6,
#          '이슈': 6,
#          '진단': 6,
#          '판매량': 6,
#          '조성은': 6,
#          '컴투스': 6,
#          '의원': 6,
#          '협회': 5,
#          '거래': 5,
#          '여야': 5,
#          '검거': 5,
#          '일': 5,
#          '롯데': 5,
#          '외인': 5,
#          '내년': 5,
#          '볼': 5,
#          '원장': 5,
#          '게임': 5,
#          '상임': 5,
#          '기념': 5,
#          '솔로': 5,
#          '여자': 5,
#          '아이유': 5,
#          '포스터': 5,
#          '윤경': 5,
#          '시스템': 5,
#          '자금': 5,
#          '어린이': 5,
#          '국가': 5,
#          '유산': 5,
#          '못': 5,
#          '비': 5,
#          '서비스': 5,
#          '경제': 5,
#          '왜': 5,
#          '동메달': 5,
#          '임애': 5,
#          '방철': 5,
#          '대회': 5,
#          '전국': 5,
#          '도중': 5,
#          '가족': 5,
#          '미소': 5,
#          '태권도': 5,
#          '분위기': 5,
#          '종': 5,
#          '혐의': 5,
#          '대비': 5,
#          '혁신': 5,
#          '기업': 5,
#          '추정': 5,
#          '우려': 5,
#          '최': 5,
#          '은': 5,
#          '에스': 5,
#          '도': 5,
#          '방': 5,
#          '트로트': 5,
#          '변경': 5,
#          '교통': 5,
#          '신호': 5,
#          '눈': 5,
#          '손흥민': 5,
#          '차': 5,
#          '평가': 5,
#          '말': 5,
#          '정부': 5,
#          '검찰': 5,
#          '확정': 5,
#          '본격': 5,
#          '커플': 5,
#          '해리스': 5,
#          '주민': 5,
#          '기': 5,
#          '그': 5,
#          '만': 5,
#          '레저': 5,
#          '영상': 5,
#          '돈': 5,
#          '관리': 5,
#          '구로역': 5,
#          '일자리': 5,
#          '예방': 5,
#          '효과': 5,
#          '연기': 5,
#          '횡단보도': 5,
#          '이동': 5,
#          '민주당': 5,
#          '지정': 5,
#          '항': 5,
#          '점검': 5,
#          '한동훈': 5,
#          '예의': 5,
#          '주시': 5,
#          '물질': 5,
#          '확인': 5,
#          '도전': 5,
#          '선정': 5,
#          '위원': 5,
#          '연': 5,
#          '새': 5,
#          '초': 5,
#          '기술': 5,
#          '달': 5,
#          '주행': 5,
#          '협의': 5,
#          '속보': 5,
#          '도슨': 5,
#          '의장': 5,
#          '방위': 5,
#          '반도체': 5,
#          '신간': 5,
#          '집': 4,
#          '간부': 4,
#          '사건': 4,
#          '보이': 4,
#          '전남': 4,
#          '지급': 4,
#          '안내': 4,
#          '구급차': 4,
#          '마카오': 4,
#          '리스트': 4,
#          '캐릭터': 4,
#          '나': 4,
#          '장관': 4,
#          '총격': 4,
#          '한인': 4,
#          '최강': 4,
#          '또': 4,
#          '콘서트': 4,
#          '메인': 4,
#          '테크놀로지': 4,
#          '뮤지컬': 4,
#          '만남': 4,
#          '업무': 4,
#          '근로자': 4,
#          '상황': 4,
#          '서프라이즈': 4,
#          '음료': 4,
#          '미국': 4,
#          '에너지': 4,
#          '협력': 4,
#          '활용': 4,
#          '입원': 4,
#          '이상': 4,
#          '건': 4,
#          '계약': 4,
#          '선': 4,
#          '축제': 4,
#          '플랫폼': 4,
#          '리그': 4,
#          '안산': 4,
#          '이관우': 4,
#          '랭킹': 4,
#          '근대': 4,
#          '라운드': 4,
#          '출시': 4,
#          '금융': 4,
#          '소비자': 4,
#          '프로': 4,
#          '그룹': 4,
#          '방지': 4,
#          '규': 4,
#          '이적': 4,
#          '손': 4,
#          '타임': 4,
#          '바이오': 4,
#          '주말': 4,
#          '연하': 4,
#          '넷마블': 4,
#          '신혼부부': 4,
#          '바이': 4,
#          '상승': 4,
#          '이원석': 4,
#          '훼손': 4,
#          '실시간': 4,
#          '실외': 4,
#          '휴가': 4,
#          '광복절': 4,
#          '특사': 4,
#          '촉구': 4,
#          '성과': 4,
#          '상반기': 4,
#          '본부장': 4,
#          '사태': 4,
#          '결혼': 4,
#          '고백': 4,
#          '연상연하': 4,
#          '패션': 4,
#          '재계약': 4,
#          '트': 4,
#          '간': 4,
#          '재단': 4,
#          '리츠': 4,
#          '감': 4,
#          '안세영': 4,
#          '발언': 4,
#          '유지': 4,
#          '축구': 4,
#          '사고': 4,
#          '방통위': 4,
#          '영어': 4,
#          '솔루션': 4,
#          '장수군': 4,
#          '시설': 4,
#          '대응': 4,
#          '특검법': 4,
#          '향': 4,
#          '일부': 4,
#          '응원': 4,
#          '비엔': 4,
#          '비만': 4,
#          '도살': 4,
#          '조치': 4,
#          '스포츠': 4,
#          '동행': 4,
#          '지자체': 4,
#          '건설': 4,
#          '강릉': 4,
#          '수주': 4,
#          '물': 4,
#          '유행': 4,
#          '리볼버': 4,
#          '배송': 4,
#          '하이': 4,
#          '국회의원': 4,
#          '테크': 4,
#          '하나': 4,
#          '유누스': 4,
#          '고문': 4,
#          '박명수': 4,
#          '뉴스': 4,
#          '북한': 4,
#          '우리': 4,
#          '업체': 4,
#          '축소': 4,
#          '긴급': 4,
#          '문화': 4,
#          '물가': 4,
#          '답': 4,
#          '종결': 3,
#          '획득': 3,
#          '처음': 3,
#          '체험': 3,
#          '민간': 3,
#          '스톡': 3,
#          '그랜트': 3,
#          '노인': 3,
#          '협치': 3,
#          '마약': 3,
#          '두': 3,
#          '가능': 3,
#          '액': 3,
#          '티': 3,
#          '이스라엘': 3,
#          '공격': 3,
#          '보복': 3,
#          '공기권총': 3,
#          '충돌': 3,
#          '이후': 3,
#          '아웃': 3,
#          '마리화나': 3,
#          '의혹': 3,
#          '사퇴': 3,
#          '다이어트': 3,
#          '해외': 3,
#          '검': 3,
#          '린': 3,
#          '타이어': 3,
#          '전북': 3,
#          '인정': 3,
#          '회견': 3,
#          '하루': 3,
#          '수도권': 3,
#          '설명': 3,
#          '비즈': 3,
#          '한미': 3,
#          '무': 3,
#          '상대': 3,
#          '현대': 3,
#          '대선': 3,
#          '아이': 3,
#          '규제': 3,
#          '햇살': 3,
#          '제이': 3,
#          '자': 3,
#          '발표': 3,
#          '전기': 3,
#          '사령탑': 3,
#          '검색': 3,
#          '엔터': 3,
#          '콘텐츠': 3,
#          '발차기': 3,
#          '경쟁': 3,
#          '홍보': 3,
#          '창업': 3,
#          '변화': 3,
#          '소식': 3,
#          '의도': 3,
#          '메달': 3,
#          '나라': 3,
#          '곳': 3,
#          '안성시': 3,
#          '군': 3,
#          '개막': 3,
#          '보건': 3,
#          '씨': 3,
#          '윈드': 3,
#          '강세': 3,
#          '시대': 3,
#          '토트넘': 3,
#          '올해': 3,
#          '퀸': 3,
#          '상품': 3,
#          '유니폼': 3,
#          '서린': 3,
#          '상사': 3,
#          '트레이딩': 3,
#          '끝': 3,
#          '경찰청': 3,
#          '진상': 3,
#          '욕': 3,
#          '총장': 3,
#          '펀드': 3,
#          '수익률': 3,
#          '연구': 3,
#          '객': 3,
#          '비밀': 3,
#          '호실': 3,
#          '방어': 3,
#          '흑자': 3,
#          '손실': 3,
#          '자회사': 3,
#          '송치': 3,
#          '위반': 3,
#          '티몬': 3,
#          '나스': 3,
#          '코너': 3,
#          '동료': 3,
#          '토론': 3,
#          '진': 3,
#          '얼굴': 3,
#          '광고': 3,
#          '주목': 3,
#          '허형': 3,
#          '키이스트': 3,
#          '의': 3,
#          '참석': 3,
#          '시민': 3,
#          '모멘텀': 3,
#          '때문': 3,
#          '친구': 3,
#          '승리': 3,
#          '출근길': 3,
#          '경기도': 3,
#          '열애': 3,
#          '넥슨': 3,
#          '질환': 3,
#          '친': 3,
#          '드림': 3,
#          '멋': 3,
#          '파트너': 3,
#          '북적': 3,
#          '고비': 3,
#          '확보': 3,
#          '관람객': 3,
#          '론': 3,
#          '김연아': 3,
#          '홀딩스': 3,
#          '라인': 3,
#          '분': 3,
#          '단아': 3,
#          '번': 3,
#          '안정환': 3,
#          '컴백': 3,
#          '작업': 3,
#          '이진숙': 3,
#          '앞': 3,
#          '매일': 3,
#          '핑크': 3,
#          '귀농': 3,
#          '귀촌': 3,
#          '한마음': 3,
#          '국가어항': 3,
#          '반포': 3,
#          '토지': 3,
#          '전현무': 3,
#          '역도': 3,
#          '당귀': 3,
#          '카타르': 3,
#          '국왕': 3,
#          '에르도안': 3,
#          '튀르키예': 3,
#          '수상': 3,
#          '단체': 3,
#          '관': 3,
#          '포함': 3,
#          '상당': 3,
#          '응급': 3,
#          '동부': 3,
#          '한화': 3,
#          '보기': 3,
#          '여름철': 3,
#          '총력': 3,
#          '위기': 3,
#          '가구': 3,
#          '허리': 3,
#          '학교': 3,
#          '민주': 3,
#          '국장': 3,
#          '피해자': 3,
#          '미모': 3,
#          '수도': 3,
#          '정': 3,
#          '신임': 3,
#          '과즙': 3,
#          '해명': 3,
#          '대북': 3,
#          '당국': 3,
#          '존': 3,
#          '캠페인': 3,
#          '축하': 3,
#          '순창군': 3,
#          '농촌': 3,
#          '순창': 3,
#          '의회': 3,
#          '슈가': 3,
#          '단독': 3,
#          '만난': 3,
#          '자율': 3,
#          '요한': 3,
#          '세트': 3,
#          '포스코': 3,
#          '랩': 3,
#          '깜짝': 3,
#          '대한민국': 3,
#          '블랙': 3,
#          '과도정부': 3,
#          '조짐': 3,
#          '자가진단': 3,
#          '수요': 3,
#          '농민': 3,
#          '속도': 3,
#          '오픈': 3,
#          '정상': 3,
#          '료': 3,
#          '라디오': 3,
#          '추진': 3,
#          '다시': 3,
#          '관광': 3,
#          '채권': 3,
#          '분석': 3,
#          '라인업': 3,
#          '머리': 3,
#          '부상': 3,
#          '브랜드': 3,
#          '이태원': 3,
#          '바로': 3,
#          '인권위': 3,
#          '두발': 3,
#          '제한': 3,
#          '총': 3,
#          '북': 3,
#          '국회': 3,
#          '토': 3,
#          '예술': 3,
#          '금': 3,
#          '집중': 3,
#          '경영': 3,
#          '전화': 3,
#          '녹취록': 3,
#          '개발': 3,
#          '사설': 3,
#          '보존': 3,
#          '가치': 3,
#          '능': 3,
#          '플러스': 3,
#          '사장': 3,
#          '부검': 2,
#          '가장': 2,
#          '김재중': 2,
#          '인기가요': 2,
#          '폭행': 2,
#          '구심': 2,
#          '영화': 2,
#          '추격자': 2,
#          '실존': 2,
#          '인물': 2,
#          '무슨': 2,
#          '관광지': 2,
#          '물산': 2,
#          '보고서': 2,
#          '발간': 2,
#          '탄소': 2,
#          '중립': 2,
#          '탈출': 2,
#          '티비': 2,
#          '고심': 2,
#          '이란': 2,
#          '시': 2,
#          '소화': 2,
#          '폭': 2,
#          '추신수': 2,
#          '시절': 2,
#          '약속': 2,
#          '주형': 2,
#          '환': 2,
#          '부위': 2,
#          '둘': 2,
#          '영웅': 2,
#          '후원': 2,
#          '절': 2,
#          '직구': 2,
#          '식품': 2,
#          '성분': 2,
#          '왕관': 2,
#          '착용': 2,
#          '를': 2,
#          '청': 2,
#          '보유': 2,
#          '발': 2,
#          '맛': 2,
#          '미식': 2,
#          '환경': 2,
#          '안전교육': 2,
#          '심민': 2,
#          '견조': 2,
#          '고려아연': 2,
#          '환원': 2,
#          '고흥군': 2,
#          '생생': 2,
#          '처방': 2,
#          '민관': 2,
#          '합의': 2,
#          '주간': 2,
#          '쇄도': 2,
#          '몸매': 2,
#          '남북': 2,
#          '복서': 2,
#          '야구': 2,
#          '예고': 2,
#          '무료': 2,
#          '터뷰': 2,
#          '시행': 2,
#          '스페셜': 2,
#          '막내': 2,
#          '착수': 2,
#          '대웅제약': 2,
#          '한국전력': 2,
#          '컨센서스': 2,
#          '대신': 2,
#          '뉴욕': 2,
#          '출연': 2,
#          '온': 2,
#          '공연': 2,
#          '자유': 2,
#          '마이': 2,
#          '개혁': 2,
#          '심의': 2,
#          '홍현희': 2,
#          '생일': 2,
#          '벌써': 2,
#          '서건우': 2,
#          '시리우스': 2,
#          '레드': 2,
#          '디자인': 2,
#          '펜싱': 2,
#          '연내': 2,
#          '모바일': 2,
#          '성폭행': 2,
#          '후계': 2,
#          '갑자기': 2,
#          '고령': 2,
#          '대리': 2,
#          '마켓': 2,
#          '복합': 2,
#          '산업': 2,
#          '압도': 2,
#          '케미칼': 2,
#          '사': 2,
#          '멸종위기': 2,
#          '달팽이': 2,
#          '마리': 2,
#          '하태도': 2,
#          '방사': 2,
#          '앤디': 2,
#          '경신': 2,
#          '발탁': 2,
#          '함평군': 2,
#          '소비': 2,
#          '공사': 2,
#          '스타': 2,
#          '조희연': 2,
#          '실질': 2,
#          '일각': 2,
#          '정치': 2,
#          '흥민': 2,
#          '이형': 2,
#          '추천': 2,
#          '복싱': 2,
#          '은감': 2,
#          '바': 2,
#          '난민': 2,
#          '선사': 2,
#          '펄': 2,
#          '어비스': 2,
#          '먼저': 2,
#          '폭풍': 2,
#          '대지진': 2,
#          '열사병': 2,
#          '기초': 2,
#          '생활': 2,
#          '산후조리': 2,
#          '교육감': 2,
#          '인성': 2,
#          '영수': 2,
#          '캠프': 2,
#          '학기': 2,
#          '줄': 2,
#          '전문가': 2,
#          '현': 2,
#          '흥행': 2,
#          '텍': 2,
#          '차이나': 2,
#          '선행': 2,
#          '개장': 2,
#          '전설': 2,
#          '눈물': 2,
#          '형': 2,
#          '히샬리송': 2,
#          '장타': 2,
#          '대결': 2,
#          '벙커': 2,
#          '문화재단': 2,
#          '출생': 2,
#          '절체절명': 2,
#          '승': 2,
#          '우승': 2,
#          '앙코르': 2,
#          '수술': 2,
#          '컬래버': 2,
#          '서머': 2,
#          '사명': 2,
#          '정체': 2,
#          '회장': 2,
#          '당선': 2,
#          '상큼': 2,
#          '엄지': 2,
#          '척': 2,
#          '제공': 2,
#          '보행자': 2,
#          '복귀': 2,
#          '영수회담': 2,
#          '현안': 2,
#          '중화권': 2,
#          '손님': 2,
#          '웃': 2,
#          '거론': 2,
#          '구속': 2,
#          '뮌헨': 2,
#          '후보자': 2,
#          '주현영': 2,
#          '월드': 2,
#          '투어': 2,
#          '광양시': 2,
#          '새내기': 2,
#          '심사': 2,
#          '연금': 2,
#          '디톡스': 2,
#          '동기': 2,
#          '전환': 2,
#          '덴티움': 2,
#          '이용': 2,
#          '미도': 2,
#          '자산': 2,
#          '예상': 2,
#          '호조': 2,
#          '상장': 2,
#          '수연': 2,
#          '유진': 2,
#          '년비': 2,
#          '누구': 2,
#          '채': 2,
#          '산': 2,
#          '남친': 2,
#          '투샷': 2,
#          '어가': 2,
#          '내달': 2,
#          '상승세': 2,
#          '대피': 2,
#          '천': 2,
#          '천우희': 2,
#          '완': 2,
#          '챔피언십': 2,
#          '식당': 2,
#          '활약': 2,
#          '연장': 2,
#          '근무': 2,
#          '현재': 2,
#          '전남대': 2,
#          '발굴': 2,
#          '반응': 2,
#          '어르신': 2,
#          '건강': 2,
#          '도입': 2,
#          '요정': 2,
#          '신작': 2,
#          '계': 2,
#          '돌입': 2,
#          '재고': 2,
#          '나선': 2,
#          '챔피언스': 2,
#          '컵': 2,
#          '비치': 2,
#          '존재': 2,
#          '우수상': 2,
#          '봄날': 2,
#          '그녀': 2,
#          '굿': 2,
#          '결승': 2,
#          '역풍': 2,
#          '야후': 2,
#          '방문객': 2,
#          '혜리': 2,
#          '계기': 2,
#          '부담': 2,
#          '시사회': 2,
#          '차량': 2,
#          '자존심': 2,
#          '우상': 2,
#          '싱글': 2,
#          '라면': 2,
#          '의왕': 2,
#          '가능성': 2,
#          '이상일': 2,
#          '용인시': 2,
#          '다이빙': 2,
#          '경기장': 2,
#          '렉': 2,
#          '트릭': 2,
#          '케이': 2,
#          '청렴': 2,
#          '눈길': 2,
#          '진입': 2,
#          '설치': 2,
#          '온스': 2,
#          '공원': 2,
#          '스프링클러': 2,
#          '원인': 2,
#          '작품': 2,
#          '공모전': 2,
#          '표': 2,
#          '허가': 2,
#          '구역': 2,
#          '이찬원': 2,
#          '소설': 2,
#          '노래': 2,
#          '데': 2,
#          '뭐': 2,
#          ...})

# %%
# 임시 딕션너리에 담아서, 필요한 부분 추출해서 조사. 
word_count = dict()

# 상위 80개 정도 
for tag, counts in count.most_common(100):
  if(len(str(tag))>1):
    word_count[tag] = counts
    # print(f" tag : {tag}, counts : {counts}")
word_count
# Out:
# {'외국인': 73,
#  '포착': 65,
#  '수급': 65,
#  '주가': 63,
#  '김예지': 57,
#  '증권': 50,
#  '리포트': 47,
#  '브리핑': 47,
#  '목표': 45,
#  '매수': 44,
#  '기관': 40,
#  '포토': 39,
#  '동시': 39,
#  '회복': 34,
#  '사격': 33,
#  '연속': 32,
#  '기자회견': 29,
#  '파리올림픽': 28,
#  '종합': 25,
#  '선수': 24,
#  '한국': 24,
#  '행진': 24,
#  '청문회': 22,
#  '삼성': 20,
#  '은메달': 19,
#  '현대차': 19,
#  '올림픽': 19,
#  '사진': 19,
#  '최고': 18,
#  '실신': 18,
#  '한복': 18,
#  '사망': 16,
#  '병원': 14,
#  '주종': 14,
#  '복권': 14,
#  '요구': 14,
#  '김경수': 13,
#  '공개': 13,
#  '영업': 13,
#  '개최': 13,
#  '코로나': 13,
#  '신고': 12,
#  '위해': 12,
#  '서울': 12,
#  '교육': 12,
#  '지역': 12,
#  '개월': 12,
#  '검사': 12,
#  '탄핵': 12,
#  '트럼프': 12,
#  '운영': 11,
#  '체결': 11,
#  '정책': 11,
#  '지원': 11,
#  '실적': 11,
#  '인상': 11,
#  '이송': 11,
#  '공급': 11,
#  '로봇': 11,
#  '국민': 11,
#  '방송': 11,
#  '지속': 10,
#  '대상': 10,
#  '성장': 10,
#  '하윤': 10,
#  '네이버': 10,
#  '화재': 10,
#  '파리': 10,
#  '교육청': 10,
#  '출석': 10,
#  '관련': 10,
#  '광주': 9,
#  '답변': 9,
#  '실시': 9,
#  '경찰': 9,
#  '세계': 9}

# %%
# 시각화1, 막대 그래프 
# 폰트 임포트 , 메모리에 설정 
font_path = "c:/Windows/Fonts/malgunbd.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
matplotlib.rc("font", family = font_name)

#, x축, y축, 가로x세로 비율, x 라벨, 폰트 설정 등
plt.figure(figsize=(12,6))
plt.xlabel("키워드")
plt.ylabel("빈도수")
plt.grid(True)

# 딕션너리의 키, 값 , 정렬 내림차순 
sorted_Keys = sorted(word_count, key=word_count.get, reverse=True)
sorted_Values = sorted(word_count.values(),reverse=True)

# 막대 그래프 그리기. 
plt.bar(range(len(word_count)), sorted_Values, align="center")

# x 축 라벨 설정. 
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation = "vertical")

plt.show()

# %%
# !pip install Numpy
# Out:
# Requirement already satisfied: Numpy in c:\python\python39\lib\site-packages (1.26.2)

# %%
# 시각화2, 워드 클라우드 
import numpy as np

import os
import re

from PIL import Image
from os import path

alice_mask = np.array(Image.open("alice_mask.png"))

# 실행시, 한글이 깨져서, 해당 폰트 패스 경로 지정 필요.
wc = WordCloud(font_path, background_color="white", max_words=1000, mask=alice_mask,width=800,height=1000)
# generate word cloud
sampleImage = wc.generate_from_frequencies(word_count)

# show
plt.imshow(sampleImage, interpolation="bilinear")
# plt.imshow(sampleImage)

plt.axis("off")
plt.show()

# %%
# 해당 출력을 이미지로 저장 하기. 
sampleImage.to_file(inputFileName + "_cloud2.jpg")
